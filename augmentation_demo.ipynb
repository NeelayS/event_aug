# %% [markdown]
# Install the `event_aug` package according to the instructions in the README.

# %%
from event_aug.spike_encoding import delta_intensity_code_video
from event_aug.spike_injection import inject_event_spikes
from event_aug.utils import array_to_video, download_from_youtube, resize_video

# %%
import numpy as np
import os
import os
import json
import tables
import cv2
import stl

# %%
WORKING_DIR = "tmp"
os.makedirs(WORKING_DIR, exist_ok=True)

# %% [markdown]
# ### Download video from YouTube

# %%
download_from_youtube(
    ["https://www.youtube.com/watch?v=cbL9NV-dStU"],
    start_times=[20],
    end_times=[110],
    save_dir=WORKING_DIR,
)
# Out:
# Downloading video 1 of 1
# ffmpeg version 4.2.2 Copyright (c) 2000-2019 the FFmpeg developers
#   built with gcc 7.3.0 (crosstool-NG 1.23.0.449-a04d0)
#   configuration: --prefix=/home/neelay/miniconda3 --cc=/tmp/build/80754af9/ffmpeg_1587154242452/_build_env/bin/x86_64-conda_cos6-linux-gnu-cc --disable-doc --enable-avresample --enable-gmp --enable-hardcoded-tables --enable-libfreetype --enable-libvpx --enable-pthreads --enable-libopus --enable-postproc --enable-pic --enable-pthreads --enable-shared --enable-static --enable-version3 --enable-zlib --enable-libmp3lame --disable-nonfree --enable-gpl --enable-gnutls --disable-openssl --enable-libopenh264 --enable-libx264
#   libavutil      56. 31.100 / 56. 31.100
#   libavcodec     58. 54.100 / 58. 54.100
#   libavformat    58. 29.100 / 58. 29.100
#   libavdevice    58.  8.100 / 58.  8.100
#   libavfilter     7. 57.100 /  7. 57.100
#   libavresample   4.  0.  0 /  4.  0.  0
#   libswscale      5.  5.100 /  5.  5.100
#   libswresample   3.  5.100 /  3.  5.100
#   libpostproc    55.  5.100 / 55.  5.100
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from 'https://rr1---sn-ci5gup-2o9z.googlevideo.com/videoplayback?expire=1660684574&ei=vrT7YrSDLtGsvcAPrv6egAk&ip=122.169.67.8&id=o-AG30qmOKeD3af5Yik7ZdlgFMZdEgsiCJY-fNa--rolH6&itag=137&aitags=133%2C134%2C135%2C136%2C137%2C160%2C242%2C243%2C244%2C247%2C248%2C278%2C394%2C395%2C396%2C397%2C398%2C399&source=youtube&requiressl=yes&mh=qd&mm=31%2C29&mn=sn-ci5gup-2o9z%2Csn-ci5gup-cvhk&ms=au%2Crdu&mv=m&mvi=1&pl=21&initcwndbps=1153750&spc=lT-KhrQ_Ya-9b9Fssrm-ioGaDoERRlc&vprv=1&mime=video%2Fmp4&ns=dejg_tAMsVqF9BZ_wnAhWUMH&gir=yes&clen=54334889&dur=136.320&lmt=1659951706582963&mt=1660662554&fvip=2&keepalive=yes&fexp=24001373%2C24007246&c=WEB&rbqsm=fr&txp=5535434&n=3MltW3NL4urtoLgtd&sparams=expire%2Cei%2Cip%2Cid%2Caitags%2Csource%2Crequiressl%2Cspc%2Cvprv%2Cmime%2Cns%2Cgir%2Cclen%2Cdur%2Clmt&sig=AOq0QJ8wRQIgcYcOZXyXtWSkV2ppnZIRSkau7vehGQr4qM8aQPru86ICIQDwIzTphIBI6gJWfcRLsH25kojdnkBnYemLntixI5npBA%3D%3D&lsparams=mh%2Cmm%2Cmn%2Cms%2Cmv%2Cmvi%2Cpl%2Cinitcwndbps&lsig=AG3C_xAwRAIgOrWgaqH4BVpbmZXmDd1-GLZYBOe2YfI5W9vT7dob4UgCIEhXz049ubrHUrQ90S4nKZneLDi7zMjODRiBUygYoXPd':
#   Metadata:
#     major_brand     : dash
#     minor_version   : 0
#     compatible_brands: iso6avc1mp41
#     creation_time   : 2022-08-08T09:29:39.000000Z
#   Duration: 00:02:16.32, start: 0.000000, bitrate: 3188 kb/s
#     Stream #0:0(und): Video: h264 (High) (avc1 / 0x31637661), yuv420p(tv, bt709, progressive), 1920x1080 [SAR 1:1 DAR 16:9], 93 kb/s, 25 fps, 25 tbr, 12800 tbn, 50 tbc (default)
#     Metadata:
#       creation_time   : 2022-08-08T09:29:39.000000Z
#       handler_name    : ISO Media file produced by Google Inc.
# Input #1, mov,mp4,m4a,3gp,3g2,mj2, from 'https://rr1---sn-ci5gup-2o9z.googlevideo.com/videoplayback?expire=1660684574&ei=vrT7YrSDLtGsvcAPrv6egAk&ip=122.169.67.8&id=o-AG30qmOKeD3af5Yik7ZdlgFMZdEgsiCJY-fNa--rolH6&itag=140&source=youtube&requiressl=yes&mh=qd&mm=31%2C29&mn=sn-ci5gup-2o9z%2Csn-ci5gup-cvhk&ms=au%2Crdu&mv=m&mvi=1&pl=21&initcwndbps=1153750&spc=lT-KhrQ_Ya-9b9Fssrm-ioGaDoERRlc&vprv=1&mime=audio%2Fmp4&ns=dejg_tAMsVqF9BZ_wnAhWUMH&gir=yes&clen=2207712&dur=136.370&lmt=1659948656625513&mt=1660662554&fvip=2&keepalive=yes&fexp=24001373%2C24007246&c=WEB&rbqsm=fr&txp=5532434&n=3MltW3NL4urtoLgtd&sparams=expire%2Cei%2Cip%2Cid%2Citag%2Csource%2Crequiressl%2Cspc%2Cvprv%2Cmime%2Cns%2Cgir%2Cclen%2Cdur%2Clmt&sig=AOq0QJ8wRQIgfGFqjTR2rhMWBN7xvhbxZtfQn2djDS3qy-oaY_IDl5cCIQDbI4kXlmXrKIfV08LbO5FvUo0VVs09W2-ZuzZQXLTjIA%3D%3D&lsparams=mh%2Cmm%2Cmn%2Cms%2Cmv%2Cmvi%2Cpl%2Cinitcwndbps&lsig=AG3C_xAwRAIgOrWgaqH4BVpbmZXmDd1-GLZYBOe2YfI5W9vT7dob4UgCIEhXz049ubrHUrQ90S4nKZneLDi7zMjODRiBUygYoXPd':
#   Metadata:
#     major_brand     : dash
#     minor_version   : 0
#     compatible_brands: iso6mp41
#     creation_time   : 2022-08-08T08:48:25.000000Z
#   Duration: 00:02:16.37, start: 0.000000, bitrate: 129 kb/s
#     Stream #1:0(eng): Audio: aac (LC) (mp4a / 0x6134706D), 44100 Hz, stereo, fltp, 9 kb/s (default)
#     Metadata:
#       creation_time   : 2022-08-08T08:48:25.000000Z
#       handler_name    : ISO Media file produced by Google Inc.
# Output #0, mp4, to 'tmp/0.mp4':
#   Metadata:
#     major_brand     : dash
#     minor_version   : 0
#     compatible_brands: iso6avc1mp41
#     encoder         : Lavf58.29.100
#     Stream #0:0(und): Video: h264 (High) (avc1 / 0x31637661), yuv420p(tv, bt709, progressive), 1920x1080 [SAR 1:1 DAR 16:9], q=2-31, 93 kb/s, 25 fps, 25 tbr, 12800 tbn, 12800 tbc (default)
#     Metadata:
#       creation_time   : 2022-08-08T09:29:39.000000Z
#       handler_name    : ISO Media file produced by Google Inc.
#     Stream #0:1(eng): Audio: aac (LC) (mp4a / 0x6134706D), 44100 Hz, stereo, fltp, 9 kb/s (default)
#     Metadata:
#       creation_time   : 2022-08-08T08:48:25.000000Z
#       handler_name    : ISO Media file produced by Google Inc.
# Stream mapping:
#   Stream #0:0 -> #0:0 (copy)
#   Stream #1:0 -> #0:1 (copy)
# Press [q] to stop, [?] for help
# frame= 2337 fps=4.1 q=-1.0 Lsize=   42041kB time=00:01:29.99 bitrate=3826.9kbits/s speed=0.157x
# video:40562kB audio:1407kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.172568%

# %% [markdown]
# ### Resize video to camera resolution

# %%
# Optional

resize_video(
    "tmp/0.mp4",
    "tmp/0_resized.mp4",
    size=(260, 346),
)
# Out:
# Original frame width: 1920, Original frame height: 1080
# Resizing to 260x346

# %% [markdown]
# ### Convert video to spikes

# %%
spikes = delta_intensity_code_video(
    "tmp/0_resized.mp4",
    percent_threshold=25,
    mode="percent_threshold",
    exclude_start=True,
    return_arr=True,
    save_video=True,
    video_save_path="tmp/encoded_vid_0.mp4",
    save_arr=True,
    arr_save_path="tmp/encoded_vid_0.npy",
)
# Out:
# Frame width: 260, Frame height: 346, Input FPS: 25, Output FPS: 25, Number of frames: 2251

# %%
spikes.shape, spikes.dtype
# Out:
# ((2251, 346, 260), dtype('bool'))

# %%
np.unique(spikes, return_counts=True)
# Out:
# (array([False,  True]), array([177172928,  25327032]))

# %% [markdown]
# ### Inject spikes into existing event sequence

# %%
event_file_path = "../projection/data/20220112_jpt_floating_kth_screwdriver/0002/orig_event.h5"
save_path = "../projection/data/20220112_jpt_floating_kth_screwdriver/0002/event.h5"

# %%
inject_event_spikes(
    event_file_path,
    save_path,
    spikes_arr=spikes, # "tmp/encoded_vid_0.npy",
    spikes_arr_from_file=False, # True
    memory_map=True, # False
    fps=100,
    label=0,
    polarity=1,
    resize_size=(260, 346),
    verbose=True,
)
# Out:
# Processing frame 0 of the event spikes video/array
# Injecting event spikes found at 0 locations in the frame
#
# Processing frame 1 of the event spikes video/array
# Injecting event spikes found at 10961 locations in the frame
#
# Processing frame 2 of the event spikes video/array
# Injecting event spikes found at 10873 locations in the frame
#
# Processing frame 3 of the event spikes video/array
# Injecting event spikes found at 11146 locations in the frame
#
# Processing frame 4 of the event spikes video/array
# Injecting event spikes found at 11050 locations in the frame
#
# Processing frame 5 of the event spikes video/array
# Injecting event spikes found at 10762 locations in the frame
#
# Processing frame 6 of the event spikes video/array
# Injecting event spikes found at 10718 locations in the frame
#
# Processing frame 7 of the event spikes video/array
# Injecting event spikes found at 11079 locations in the frame
#
# Processing frame 8 of the event spikes video/array
# Injecting event spikes found at 10701 locations in the frame
#
# Processing frame 9 of the event spikes video/array
# Injecting event spikes found at 10533 locations in the frame
#
# Processing frame 10 of the event spikes video/array
# Injecting event spikes found at 10538 locations in the frame
#
# Processing frame 11 of the event spikes video/array
# Injecting event spikes found at 10561 locations in the frame
#
# Processing frame 12 of the event spikes video/array
# Injecting event spikes found at 10538 locations in the frame
#
# Processing frame 13 of the event spikes video/array
# Injecting event spikes found at 10659 locations in the frame
#
# Processing frame 14 of the event spikes video/array
# Injecting event spikes found at 10634 locations in the frame
#
# Processing frame 15 of the event spikes video/array
# Injecting event spikes found at 10244 locations in the frame
#
# Processing frame 16 of the event spikes video/array
# Injecting event spikes found at 10963 locations in the frame
#
# Processing frame 17 of the event spikes video/array
# Injecting event spikes found at 10447 locations in the frame
#
# Processing frame 18 of the event spikes video/array
# Injecting event spikes found at 10089 locations in the frame
#
# Processing frame 19 of the event spikes video/array
# Injecting event spikes found at 10094 locations in the frame
#
# Processing frame 20 of the event spikes video/array
# Injecting event spikes found at 10622 locations in the frame
#
# Processing frame 21 of the event spikes video/array
# Injecting event spikes found at 10259 locations in the frame
#
# Processing frame 22 of the event spikes video/array
# Injecting event spikes found at 9977 locations in the frame
#
# Processing frame 23 of the event spikes video/array
# Injecting event spikes found at 9301 locations in the frame
#
# Processing frame 24 of the event spikes video/array
# Injecting event spikes found at 9488 locations in the frame
#
# Processing frame 25 of the event spikes video/array
# Injecting event spikes found at 9397 locations in the frame
#
# Processing frame 26 of the event spikes video/array
# Injecting event spikes found at 9522 locations in the frame
#
# Processing frame 27 of the event spikes video/array
# Injecting event spikes found at 9478 locations in the frame
#
# Processing frame 28 of the event spikes video/array
# Injecting event spikes found at 8398 locations in the frame
#
# Processing frame 29 of the event spikes video/array
# Injecting event spikes found at 8924 locations in the frame
#
# Processing frame 30 of the event spikes video/array
# Injecting event spikes found at 9257 locations in the frame
#
# Processing frame 31 of the event spikes video/array
# Injecting event spikes found at 8513 locations in the frame
#
# Processing frame 32 of the event spikes video/array
# Injecting event spikes found at 9151 locations in the frame
#
# Processing frame 33 of the event spikes video/array
# Injecting event spikes found at 9016 locations in the frame
#
# Processing frame 34 of the event spikes video/array
# Injecting event spikes found at 8328 locations in the frame
#
# Processing frame 35 of the event spikes video/array
# Injecting event spikes found at 8269 locations in the frame
#
# Processing frame 36 of the event spikes video/array
# Injecting event spikes found at 8736 locations in the frame
#
# Processing frame 37 of the event spikes video/array
# Injecting event spikes found at 8249 locations in the frame
#
# Processing frame 38 of the event spikes video/array
# Injecting event spikes found at 8428 locations in the frame
#
# Processing frame 39 of the event spikes video/array
# Injecting event spikes found at 8661 locations in the frame
#
# Processing frame 40 of the event spikes video/array
# Injecting event spikes found at 9160 locations in the frame
#
# Processing frame 41 of the event spikes video/array
# Injecting event spikes found at 10048 locations in the frame
#
# Processing frame 42 of the event spikes video/array
# Injecting event spikes found at 10378 locations in the frame
#
# Processing frame 43 of the event spikes video/array
# Injecting event spikes found at 10433 locations in the frame
#
# Processing frame 44 of the event spikes video/array
# Injecting event spikes found at 10333 locations in the frame
#
# Processing frame 45 of the event spikes video/array
# Injecting event spikes found at 10310 locations in the frame
#
# Processing frame 46 of the event spikes video/array
# Injecting event spikes found at 10318 locations in the frame
#
# Processing frame 47 of the event spikes video/array
# Injecting event spikes found at 9623 locations in the frame
#
# Processing frame 48 of the event spikes video/array
# Injecting event spikes found at 9418 locations in the frame
#
# Processing frame 49 of the event spikes video/array
# Injecting event spikes found at 8953 locations in the frame
#
# Processing frame 50 of the event spikes video/array
# Injecting event spikes found at 7998 locations in the frame
#
# Processing frame 51 of the event spikes video/array
# Injecting event spikes found at 7747 locations in the frame
#
# Processing frame 52 of the event spikes video/array
# Injecting event spikes found at 7100 locations in the frame
#
# Processing frame 53 of the event spikes video/array
# Injecting event spikes found at 7250 locations in the frame
#
# Processing frame 54 of the event spikes video/array
# Injecting event spikes found at 8385 locations in the frame
#
# Processing frame 55 of the event spikes video/array
# Injecting event spikes found at 7664 locations in the frame
#
# Processing frame 56 of the event spikes video/array
# Injecting event spikes found at 3846 locations in the frame
#
# Processing frame 57 of the event spikes video/array
# Injecting event spikes found at 2062 locations in the frame
#
# Processing frame 58 of the event spikes video/array
# Injecting event spikes found at 2785 locations in the frame
#
# Processing frame 59 of the event spikes video/array
# Injecting event spikes found at 3945 locations in the frame
#
# Processing frame 60 of the event spikes video/array
# Injecting event spikes found at 6730 locations in the frame
#
# Processing frame 61 of the event spikes video/array
# Injecting event spikes found at 7719 locations in the frame
#
# Processing frame 62 of the event spikes video/array
# Injecting event spikes found at 8774 locations in the frame
#
# Processing frame 63 of the event spikes video/array
# Injecting event spikes found at 10211 locations in the frame
#
# Processing frame 64 of the event spikes video/array
# Injecting event spikes found at 11162 locations in the frame
#
# Processing frame 65 of the event spikes video/array
# Injecting event spikes found at 11951 locations in the frame
#
# Processing frame 66 of the event spikes video/array
# Injecting event spikes found at 12499 locations in the frame
#
# Processing frame 67 of the event spikes video/array
# Injecting event spikes found at 12803 locations in the frame
#
# Processing frame 68 of the event spikes video/array
# Injecting event spikes found at 12672 locations in the frame
#
# Processing frame 69 of the event spikes video/array
# Injecting event spikes found at 11176 locations in the frame
#
# Processing frame 70 of the event spikes video/array
# Injecting event spikes found at 10147 locations in the frame
#
# Processing frame 71 of the event spikes video/array
# Injecting event spikes found at 9339 locations in the frame
#
# Processing frame 72 of the event spikes video/array
# Injecting event spikes found at 8177 locations in the frame
#
# Processing frame 73 of the event spikes video/array
# Injecting event spikes found at 6721 locations in the frame
#
# Processing frame 74 of the event spikes video/array
# Injecting event spikes found at 6271 locations in the frame
#
# Processing frame 75 of the event spikes video/array
# Injecting event spikes found at 6473 locations in the frame
#
# Processing frame 76 of the event spikes video/array
# Injecting event spikes found at 5467 locations in the frame
#
# Processing frame 77 of the event spikes video/array
# Injecting event spikes found at 3788 locations in the frame
#
# Processing frame 78 of the event spikes video/array
# Injecting event spikes found at 5567 locations in the frame
#
# Processing frame 79 of the event spikes video/array
# Injecting event spikes found at 6565 locations in the frame
#
# Processing frame 80 of the event spikes video/array
# Injecting event spikes found at 7941 locations in the frame
#
# Processing frame 81 of the event spikes video/array
# Injecting event spikes found at 8491 locations in the frame
#
# Processing frame 82 of the event spikes video/array
# Injecting event spikes found at 9366 locations in the frame
#
# Processing frame 83 of the event spikes video/array
# Injecting event spikes found at 9727 locations in the frame
#
# Processing frame 84 of the event spikes video/array
# Injecting event spikes found at 9946 locations in the frame
#
# Processing frame 85 of the event spikes video/array
# Injecting event spikes found at 8502 locations in the frame
#
# Processing frame 86 of the event spikes video/array
# Injecting event spikes found at 5601 locations in the frame
#
# Processing frame 87 of the event spikes video/array
# Injecting event spikes found at 3302 locations in the frame
#
# Processing frame 88 of the event spikes video/array
# Injecting event spikes found at 2331 locations in the frame
#
# Processing frame 89 of the event spikes video/array
# Injecting event spikes found at 2826 locations in the frame
#
# Processing frame 90 of the event spikes video/array
# Injecting event spikes found at 3431 locations in the frame
#
# Processing frame 91 of the event spikes video/array
# Injecting event spikes found at 3685 locations in the frame
#
# Processing frame 92 of the event spikes video/array
# Injecting event spikes found at 4836 locations in the frame
#
# Processing frame 93 of the event spikes video/array
# Injecting event spikes found at 4431 locations in the frame
#
# Processing frame 94 of the event spikes video/array
# Injecting event spikes found at 4262 locations in the frame
#
# Processing frame 95 of the event spikes video/array
# Injecting event spikes found at 6085 locations in the frame
#
# Processing frame 96 of the event spikes video/array
# Injecting event spikes found at 5723 locations in the frame
#
# Processing frame 97 of the event spikes video/array
# Injecting event spikes found at 4995 locations in the frame
#
# Processing frame 98 of the event spikes video/array
# Injecting event spikes found at 5874 locations in the frame
#
# Processing frame 99 of the event spikes video/array
# Injecting event spikes found at 4510 locations in the frame
#
# Processing frame 100 of the event spikes video/array
# Injecting event spikes found at 4260 locations in the frame
#
# Processing frame 101 of the event spikes video/array
# Injecting event spikes found at 4723 locations in the frame
#
# Processing frame 102 of the event spikes video/array
# Injecting event spikes found at 4820 locations in the frame
#
# Processing frame 103 of the event spikes video/array
# Injecting event spikes found at 3631 locations in the frame
#
# Processing frame 104 of the event spikes video/array
# Injecting event spikes found at 3394 locations in the frame
#
# Processing frame 105 of the event spikes video/array
# Injecting event spikes found at 4075 locations in the frame
#
# Processing frame 106 of the event spikes video/array
# Injecting event spikes found at 3707 locations in the frame
#
# Processing frame 107 of the event spikes video/array
# Injecting event spikes found at 3243 locations in the frame
#
# Processing frame 108 of the event spikes video/array
# Injecting event spikes found at 3404 locations in the frame
#
# Processing frame 109 of the event spikes video/array
# Injecting event spikes found at 1310 locations in the frame
#
# Processing frame 110 of the event spikes video/array
# Injecting event spikes found at 1148 locations in the frame
#
# Processing frame 111 of the event spikes video/array
# Injecting event spikes found at 1010 locations in the frame
#
# Processing frame 112 of the event spikes video/array
# Injecting event spikes found at 843 locations in the frame
#
# Processing frame 113 of the event spikes video/array
# Injecting event spikes found at 904 locations in the frame
#
# Processing frame 114 of the event spikes video/array
# Injecting event spikes found at 933 locations in the frame
#
# Processing frame 115 of the event spikes video/array
# Injecting event spikes found at 1022 locations in the frame
#
# Processing frame 116 of the event spikes video/array
# Injecting event spikes found at 1084 locations in the frame
#
# Processing frame 117 of the event spikes video/array
# Injecting event spikes found at 1095 locations in the frame
#
# Processing frame 118 of the event spikes video/array
# Injecting event spikes found at 896 locations in the frame
#
# Processing frame 119 of the event spikes video/array
# Injecting event spikes found at 911 locations in the frame
#
# Processing frame 120 of the event spikes video/array
# Injecting event spikes found at 1358 locations in the frame
#
# Processing frame 121 of the event spikes video/array
# Injecting event spikes found at 1298 locations in the frame
#
# Processing frame 122 of the event spikes video/array
# Injecting event spikes found at 837 locations in the frame
#
# Processing frame 123 of the event spikes video/array
# Injecting event spikes found at 908 locations in the frame
#
# Processing frame 124 of the event spikes video/array
# Injecting event spikes found at 2954 locations in the frame
#
# Processing frame 125 of the event spikes video/array
# Injecting event spikes found at 3407 locations in the frame
#
# Processing frame 126 of the event spikes video/array
# Injecting event spikes found at 3074 locations in the frame
#
# Processing frame 127 of the event spikes video/array
# Injecting event spikes found at 2112 locations in the frame
#
# Processing frame 128 of the event spikes video/array
# Injecting event spikes found at 1319 locations in the frame
#
# Processing frame 129 of the event spikes video/array
# Injecting event spikes found at 781 locations in the frame
#
# Processing frame 130 of the event spikes video/array
# Injecting event spikes found at 904 locations in the frame
#
# Processing frame 131 of the event spikes video/array
# Injecting event spikes found at 1081 locations in the frame
#
# Processing frame 132 of the event spikes video/array
# Injecting event spikes found at 2866 locations in the frame
#
# Processing frame 133 of the event spikes video/array
# Injecting event spikes found at 744 locations in the frame
#
# Processing frame 134 of the event spikes video/array
# Injecting event spikes found at 795 locations in the frame
#
# Processing frame 135 of the event spikes video/array
# Injecting event spikes found at 843 locations in the frame
#
# Processing frame 136 of the event spikes video/array
# Injecting event spikes found at 2755 locations in the frame
#
# Processing frame 137 of the event spikes video/array
# Injecting event spikes found at 2858 locations in the frame
#
# Processing frame 138 of the event spikes video/array
# Injecting event spikes found at 70581 locations in the frame
#
# Processing frame 139 of the event spikes video/array
# Injecting event spikes found at 31424 locations in the frame
#
# Processing frame 140 of the event spikes video/array
# Injecting event spikes found at 27059 locations in the frame
#
# Processing frame 141 of the event spikes video/array
# Injecting event spikes found at 51982 locations in the frame
#
# Processing frame 142 of the event spikes video/array
# Injecting event spikes found at 29601 locations in the frame
#
# Processing frame 143 of the event spikes video/array
# Injecting event spikes found at 60175 locations in the frame
#
# Processing frame 144 of the event spikes video/array
# Injecting event spikes found at 51180 locations in the frame
#
# Processing frame 145 of the event spikes video/array
# Injecting event spikes found at 50729 locations in the frame
#
# Processing frame 146 of the event spikes video/array
# Injecting event spikes found at 40982 locations in the frame
#
# Processing frame 147 of the event spikes video/array
# Injecting event spikes found at 37599 locations in the frame
#
# Processing frame 148 of the event spikes video/array
# Injecting event spikes found at 43257 locations in the frame
#
# Processing frame 149 of the event spikes video/array
# Injecting event spikes found at 42628 locations in the frame
#
# Processing frame 150 of the event spikes video/array
# Injecting event spikes found at 39555 locations in the frame
#
# Processing frame 151 of the event spikes video/array
# Injecting event spikes found at 48803 locations in the frame
#
# Processing frame 152 of the event spikes video/array
# Injecting event spikes found at 54960 locations in the frame
#
# Processing frame 153 of the event spikes video/array
# Injecting event spikes found at 49653 locations in the frame
#
# Processing frame 154 of the event spikes video/array
# Injecting event spikes found at 10630 locations in the frame
#
# Processing frame 155 of the event spikes video/array
# Injecting event spikes found at 10976 locations in the frame
#
# Processing frame 156 of the event spikes video/array
# Injecting event spikes found at 9161 locations in the frame
#
# Processing frame 157 of the event spikes video/array
# Injecting event spikes found at 10697 locations in the frame
#
# Processing frame 158 of the event spikes video/array
# Injecting event spikes found at 10727 locations in the frame
#
# Processing frame 159 of the event spikes video/array
# Injecting event spikes found at 10374 locations in the frame
#
# Processing frame 160 of the event spikes video/array
# Injecting event spikes found at 11280 locations in the frame
#
# Processing frame 161 of the event spikes video/array
# Injecting event spikes found at 12834 locations in the frame
#
# Processing frame 162 of the event spikes video/array
# Injecting event spikes found at 12577 locations in the frame
#
# Processing frame 163 of the event spikes video/array
# Injecting event spikes found at 12240 locations in the frame
#
# Processing frame 164 of the event spikes video/array
# Injecting event spikes found at 15022 locations in the frame
#
# Processing frame 165 of the event spikes video/array
# Injecting event spikes found at 18222 locations in the frame
#
# Processing frame 166 of the event spikes video/array
# Injecting event spikes found at 19113 locations in the frame
#
# Processing frame 167 of the event spikes video/array
# Injecting event spikes found at 16453 locations in the frame
#
# Processing frame 168 of the event spikes video/array
# Injecting event spikes found at 14539 locations in the frame
#
# Processing frame 169 of the event spikes video/array
# Injecting event spikes found at 17887 locations in the frame
#
# Processing frame 170 of the event spikes video/array
# Injecting event spikes found at 19716 locations in the frame
#
# Processing frame 171 of the event spikes video/array
# Injecting event spikes found at 17219 locations in the frame
#
# Processing frame 172 of the event spikes video/array
# Injecting event spikes found at 15250 locations in the frame
#
# Processing frame 173 of the event spikes video/array
# Injecting event spikes found at 10026 locations in the frame
#
# Processing frame 174 of the event spikes video/array
# Injecting event spikes found at 14658 locations in the frame
#
# Processing frame 175 of the event spikes video/array
# Injecting event spikes found at 12428 locations in the frame
#
# Processing frame 176 of the event spikes video/array
# Injecting event spikes found at 10916 locations in the frame
#
# Processing frame 177 of the event spikes video/array
# Injecting event spikes found at 14146 locations in the frame
#
# Processing frame 178 of the event spikes video/array
# Injecting event spikes found at 16474 locations in the frame
#
# Processing frame 179 of the event spikes video/array
# Injecting event spikes found at 15422 locations in the frame
#
# Processing frame 180 of the event spikes video/array
# Injecting event spikes found at 17314 locations in the frame
#
# Processing frame 181 of the event spikes video/array
# Injecting event spikes found at 18092 locations in the frame
#
# Processing frame 182 of the event spikes video/array
# Injecting event spikes found at 25571 locations in the frame
#
# Processing frame 183 of the event spikes video/array
# Injecting event spikes found at 30223 locations in the frame
#
# Processing frame 184 of the event spikes video/array
# Injecting event spikes found at 33126 locations in the frame
#
# Processing frame 185 of the event spikes video/array
# Injecting event spikes found at 33502 locations in the frame
#
# Processing frame 186 of the event spikes video/array
# Injecting event spikes found at 33353 locations in the frame
#
# Processing frame 187 of the event spikes video/array
# Injecting event spikes found at 36606 locations in the frame
#
# Processing frame 188 of the event spikes video/array
# Injecting event spikes found at 35414 locations in the frame
#
# Processing frame 189 of the event spikes video/array
# Injecting event spikes found at 35195 locations in the frame
#
# Processing frame 190 of the event spikes video/array
# Injecting event spikes found at 38546 locations in the frame
#
# Processing frame 191 of the event spikes video/array
# Injecting event spikes found at 37497 locations in the frame
#
# Processing frame 192 of the event spikes video/array
# Injecting event spikes found at 31632 locations in the frame
#
# Processing frame 193 of the event spikes video/array
# Injecting event spikes found at 26945 locations in the frame
#
# Processing frame 194 of the event spikes video/array
# Injecting event spikes found at 29577 locations in the frame
#
# Processing frame 195 of the event spikes video/array
# Injecting event spikes found at 25867 locations in the frame
#
# Processing frame 196 of the event spikes video/array
# Injecting event spikes found at 18879 locations in the frame
#
# Processing frame 197 of the event spikes video/array
# Injecting event spikes found at 15750 locations in the frame
#
# Processing frame 198 of the event spikes video/array
# Injecting event spikes found at 16145 locations in the frame
#
# Processing frame 199 of the event spikes video/array
# Injecting event spikes found at 16801 locations in the frame
#
# Processing frame 200 of the event spikes video/array
# Injecting event spikes found at 18411 locations in the frame
#
# Processing frame 201 of the event spikes video/array
# Injecting event spikes found at 16817 locations in the frame
#
# Processing frame 202 of the event spikes video/array
# Injecting event spikes found at 13738 locations in the frame
#
# Processing frame 203 of the event spikes video/array
# Injecting event spikes found at 14289 locations in the frame
#
# Processing frame 204 of the event spikes video/array
# Injecting event spikes found at 13866 locations in the frame
#
# Processing frame 205 of the event spikes video/array
# Injecting event spikes found at 14632 locations in the frame
#
# Processing frame 206 of the event spikes video/array
# Injecting event spikes found at 13235 locations in the frame
#
# Processing frame 207 of the event spikes video/array
# Injecting event spikes found at 10449 locations in the frame
#
# Processing frame 208 of the event spikes video/array
# Injecting event spikes found at 6877 locations in the frame
#
# Processing frame 209 of the event spikes video/array
# Injecting event spikes found at 5062 locations in the frame
#
# Processing frame 210 of the event spikes video/array
# Injecting event spikes found at 4148 locations in the frame
#
# Processing frame 211 of the event spikes video/array
# Injecting event spikes found at 3226 locations in the frame
#
# Processing frame 212 of the event spikes video/array
# Injecting event spikes found at 3747 locations in the frame
#
# Processing frame 213 of the event spikes video/array
# Injecting event spikes found at 4623 locations in the frame
#
# Processing frame 214 of the event spikes video/array
# Injecting event spikes found at 5164 locations in the frame
#
# Processing frame 215 of the event spikes video/array
# Injecting event spikes found at 5077 locations in the frame
#
# Processing frame 216 of the event spikes video/array
# Injecting event spikes found at 5688 locations in the frame
#
# Processing frame 217 of the event spikes video/array
# Injecting event spikes found at 6885 locations in the frame
#
# Processing frame 218 of the event spikes video/array
# Injecting event spikes found at 6610 locations in the frame
#
# Processing frame 219 of the event spikes video/array
# Injecting event spikes found at 6535 locations in the frame
#
# Processing frame 220 of the event spikes video/array
# Injecting event spikes found at 8033 locations in the frame
#
# Processing frame 221 of the event spikes video/array
# Injecting event spikes found at 8066 locations in the frame
#
# Processing frame 222 of the event spikes video/array
# Injecting event spikes found at 6570 locations in the frame
#
# Processing frame 223 of the event spikes video/array
# Injecting event spikes found at 5900 locations in the frame
#
# Processing frame 224 of the event spikes video/array
# Injecting event spikes found at 6727 locations in the frame
#
# Processing frame 225 of the event spikes video/array
# Injecting event spikes found at 7855 locations in the frame
#
# Processing frame 226 of the event spikes video/array
# Injecting event spikes found at 11461 locations in the frame
#
# Processing frame 227 of the event spikes video/array
# Injecting event spikes found at 14276 locations in the frame
#
# Processing frame 228 of the event spikes video/array
# Injecting event spikes found at 15389 locations in the frame
#
# Processing frame 229 of the event spikes video/array
# Injecting event spikes found at 16753 locations in the frame
#
# Processing frame 230 of the event spikes video/array
# Injecting event spikes found at 17131 locations in the frame
#
# Processing frame 231 of the event spikes video/array
# Injecting event spikes found at 15867 locations in the frame
#
# Processing frame 232 of the event spikes video/array
# Injecting event spikes found at 15246 locations in the frame
#
# Processing frame 233 of the event spikes video/array
# Injecting event spikes found at 15300 locations in the frame
#
# Processing frame 234 of the event spikes video/array
# Injecting event spikes found at 15355 locations in the frame
#
# Processing frame 235 of the event spikes video/array
# Injecting event spikes found at 13430 locations in the frame
#
# Processing frame 236 of the event spikes video/array
# Injecting event spikes found at 12095 locations in the frame
#
# Processing frame 237 of the event spikes video/array
# Injecting event spikes found at 10492 locations in the frame
#
# Processing frame 238 of the event spikes video/array
# Injecting event spikes found at 8122 locations in the frame
#
# Processing frame 239 of the event spikes video/array
# Injecting event spikes found at 6207 locations in the frame
#
# Processing frame 240 of the event spikes video/array
# Injecting event spikes found at 5432 locations in the frame
#
# Processing frame 241 of the event spikes video/array
# Injecting event spikes found at 4222 locations in the frame
#
# Processing frame 242 of the event spikes video/array
# Injecting event spikes found at 3426 locations in the frame
#
# Processing frame 243 of the event spikes video/array
# Injecting event spikes found at 4623 locations in the frame
#
# Processing frame 244 of the event spikes video/array
# Injecting event spikes found at 5594 locations in the frame
#
# Processing frame 245 of the event spikes video/array
# Injecting event spikes found at 7235 locations in the frame
#
# Processing frame 246 of the event spikes video/array
# Injecting event spikes found at 9615 locations in the frame
#
# Processing frame 247 of the event spikes video/array
# Injecting event spikes found at 11315 locations in the frame
#
# Processing frame 248 of the event spikes video/array
# Injecting event spikes found at 13871 locations in the frame
#
# Processing frame 249 of the event spikes video/array
# Injecting event spikes found at 14988 locations in the frame
#
# Processing frame 250 of the event spikes video/array
# Injecting event spikes found at 15542 locations in the frame
#
# Processing frame 251 of the event spikes video/array
# Injecting event spikes found at 15227 locations in the frame
#
# Processing frame 252 of the event spikes video/array
# Injecting event spikes found at 13995 locations in the frame
#
# Processing frame 253 of the event spikes video/array
# Injecting event spikes found at 12555 locations in the frame
#
# Processing frame 254 of the event spikes video/array
# Injecting event spikes found at 11468 locations in the frame
#
# Processing frame 255 of the event spikes video/array
# Injecting event spikes found at 9754 locations in the frame
#
# Processing frame 256 of the event spikes video/array
# Injecting event spikes found at 8750 locations in the frame
#
# Processing frame 257 of the event spikes video/array
# Injecting event spikes found at 8694 locations in the frame
#
# Processing frame 258 of the event spikes video/array
# Injecting event spikes found at 8087 locations in the frame
#
# Processing frame 259 of the event spikes video/array
# Injecting event spikes found at 8367 locations in the frame
#
# Processing frame 260 of the event spikes video/array
# Injecting event spikes found at 9659 locations in the frame
#
# Processing frame 261 of the event spikes video/array
# Injecting event spikes found at 10808 locations in the frame
#
# Processing frame 262 of the event spikes video/array
# Injecting event spikes found at 11243 locations in the frame
#
# Processing frame 263 of the event spikes video/array
# Injecting event spikes found at 12382 locations in the frame
#
# Processing frame 264 of the event spikes video/array
# Injecting event spikes found at 14151 locations in the frame
#
# Processing frame 265 of the event spikes video/array
# Injecting event spikes found at 13523 locations in the frame
#
# Processing frame 266 of the event spikes video/array
# Injecting event spikes found at 12471 locations in the frame
#
# Processing frame 267 of the event spikes video/array
# Injecting event spikes found at 11187 locations in the frame
#
# Processing frame 268 of the event spikes video/array
# Injecting event spikes found at 10925 locations in the frame
#
# Processing frame 269 of the event spikes video/array
# Injecting event spikes found at 10692 locations in the frame
#
# Processing frame 270 of the event spikes video/array
# Injecting event spikes found at 9870 locations in the frame
#
# Processing frame 271 of the event spikes video/array
# Injecting event spikes found at 9360 locations in the frame
#
# Processing frame 272 of the event spikes video/array
# Injecting event spikes found at 9152 locations in the frame
#
# Processing frame 273 of the event spikes video/array
# Injecting event spikes found at 9130 locations in the frame
#
# Processing frame 274 of the event spikes video/array
# Injecting event spikes found at 8841 locations in the frame
#
# Processing frame 275 of the event spikes video/array
# Injecting event spikes found at 7342 locations in the frame
#
# Processing frame 276 of the event spikes video/array
# Injecting event spikes found at 6981 locations in the frame
#
# Processing frame 277 of the event spikes video/array
# Injecting event spikes found at 7151 locations in the frame
#
# Processing frame 278 of the event spikes video/array
# Injecting event spikes found at 7854 locations in the frame
#
# Processing frame 279 of the event spikes video/array
# Injecting event spikes found at 8022 locations in the frame
#
# Processing frame 280 of the event spikes video/array
# Injecting event spikes found at 7800 locations in the frame
#
# Processing frame 281 of the event spikes video/array
# Injecting event spikes found at 8206 locations in the frame
#
# Processing frame 282 of the event spikes video/array
# Injecting event spikes found at 7964 locations in the frame
#
# Processing frame 283 of the event spikes video/array
# Injecting event spikes found at 7414 locations in the frame
#
# Processing frame 284 of the event spikes video/array
# Injecting event spikes found at 7278 locations in the frame
#
# Processing frame 285 of the event spikes video/array
# Injecting event spikes found at 7509 locations in the frame
#
# Processing frame 286 of the event spikes video/array
# Injecting event spikes found at 7350 locations in the frame
#
# Processing frame 287 of the event spikes video/array
# Injecting event spikes found at 7318 locations in the frame
#
# Processing frame 288 of the event spikes video/array
# Injecting event spikes found at 7534 locations in the frame
#
# Processing frame 289 of the event spikes video/array
# Injecting event spikes found at 7642 locations in the frame
#
# Processing frame 290 of the event spikes video/array
# Injecting event spikes found at 7983 locations in the frame
#
# Processing frame 291 of the event spikes video/array
# Injecting event spikes found at 7722 locations in the frame
#
# Processing frame 292 of the event spikes video/array
# Injecting event spikes found at 7980 locations in the frame
#
# Processing frame 293 of the event spikes video/array
# Injecting event spikes found at 8178 locations in the frame
#
# Processing frame 294 of the event spikes video/array
# Injecting event spikes found at 8439 locations in the frame
#
# Processing frame 295 of the event spikes video/array
# Injecting event spikes found at 8281 locations in the frame
#
# Processing frame 296 of the event spikes video/array
# Injecting event spikes found at 8463 locations in the frame
#
# Processing frame 297 of the event spikes video/array
# Injecting event spikes found at 8447 locations in the frame
#
# Processing frame 298 of the event spikes video/array
# Injecting event spikes found at 8233 locations in the frame
#
# Processing frame 299 of the event spikes video/array
# Injecting event spikes found at 7984 locations in the frame
#
# Processing frame 300 of the event spikes video/array
# Injecting event spikes found at 8256 locations in the frame
#
# Processing frame 301 of the event spikes video/array
# Injecting event spikes found at 7996 locations in the frame
#
# Processing frame 302 of the event spikes video/array
# Injecting event spikes found at 8432 locations in the frame
#
# Processing frame 303 of the event spikes video/array
# Injecting event spikes found at 8838 locations in the frame
#
# Processing frame 304 of the event spikes video/array
# Injecting event spikes found at 8773 locations in the frame
#
# Processing frame 305 of the event spikes video/array
# Injecting event spikes found at 8161 locations in the frame
#
# Processing frame 306 of the event spikes video/array
# Injecting event spikes found at 7746 locations in the frame
#
# Processing frame 307 of the event spikes video/array
# Injecting event spikes found at 7711 locations in the frame
#
# Processing frame 308 of the event spikes video/array
# Injecting event spikes found at 8483 locations in the frame
#
# Processing frame 309 of the event spikes video/array
# Injecting event spikes found at 8423 locations in the frame
#
# Processing frame 310 of the event spikes video/array
# Injecting event spikes found at 8811 locations in the frame
#
# Processing frame 311 of the event spikes video/array
# Injecting event spikes found at 8596 locations in the frame
#
# Processing frame 312 of the event spikes video/array
# Injecting event spikes found at 8142 locations in the frame
#
# Processing frame 313 of the event spikes video/array
# Injecting event spikes found at 8324 locations in the frame
#
# Processing frame 314 of the event spikes video/array
# Injecting event spikes found at 9246 locations in the frame
#
# Processing frame 315 of the event spikes video/array
# Injecting event spikes found at 10442 locations in the frame
#
# Processing frame 316 of the event spikes video/array
# Injecting event spikes found at 12032 locations in the frame
#
# Processing frame 317 of the event spikes video/array
# Injecting event spikes found at 13287 locations in the frame
#
# Processing frame 318 of the event spikes video/array
# Injecting event spikes found at 14219 locations in the frame
#
# Processing frame 319 of the event spikes video/array
# Injecting event spikes found at 16132 locations in the frame
#
# Processing frame 320 of the event spikes video/array
# Injecting event spikes found at 18164 locations in the frame
#
# Processing frame 321 of the event spikes video/array
# Injecting event spikes found at 18634 locations in the frame
#
# Processing frame 322 of the event spikes video/array
# Injecting event spikes found at 19105 locations in the frame
#
# Processing frame 323 of the event spikes video/array
# Injecting event spikes found at 19776 locations in the frame
#
# Processing frame 324 of the event spikes video/array
# Injecting event spikes found at 20329 locations in the frame
#
# Processing frame 325 of the event spikes video/array
# Injecting event spikes found at 20975 locations in the frame
#
# Processing frame 326 of the event spikes video/array
# Injecting event spikes found at 20973 locations in the frame
#
# Processing frame 327 of the event spikes video/array
# Injecting event spikes found at 20906 locations in the frame
#
# Processing frame 328 of the event spikes video/array
# Injecting event spikes found at 19683 locations in the frame
#
# Processing frame 329 of the event spikes video/array
# Injecting event spikes found at 18904 locations in the frame
#
# Processing frame 330 of the event spikes video/array
# Injecting event spikes found at 18657 locations in the frame
#
# Processing frame 331 of the event spikes video/array
# Injecting event spikes found at 16875 locations in the frame
#
# Processing frame 332 of the event spikes video/array
# Injecting event spikes found at 15689 locations in the frame
#
# Processing frame 333 of the event spikes video/array
# Injecting event spikes found at 15760 locations in the frame
#
# Processing frame 334 of the event spikes video/array
# Injecting event spikes found at 16575 locations in the frame
#
# Processing frame 335 of the event spikes video/array
# Injecting event spikes found at 18191 locations in the frame
#
# Processing frame 336 of the event spikes video/array
# Injecting event spikes found at 19633 locations in the frame
#
# Processing frame 337 of the event spikes video/array
# Injecting event spikes found at 20384 locations in the frame
#
# Processing frame 338 of the event spikes video/array
# Injecting event spikes found at 21410 locations in the frame
#
# Processing frame 339 of the event spikes video/array
# Injecting event spikes found at 22123 locations in the frame
#
# Processing frame 340 of the event spikes video/array
# Injecting event spikes found at 22326 locations in the frame
#
# Processing frame 341 of the event spikes video/array
# Injecting event spikes found at 22941 locations in the frame
#
# Processing frame 342 of the event spikes video/array
# Injecting event spikes found at 23600 locations in the frame
#
# Processing frame 343 of the event spikes video/array
# Injecting event spikes found at 23994 locations in the frame
#
# Processing frame 344 of the event spikes video/array
# Injecting event spikes found at 23958 locations in the frame
#
# Processing frame 345 of the event spikes video/array
# Injecting event spikes found at 22933 locations in the frame
#
# Processing frame 346 of the event spikes video/array
# Injecting event spikes found at 22213 locations in the frame
#
# Processing frame 347 of the event spikes video/array
# Injecting event spikes found at 22495 locations in the frame
#
# Processing frame 348 of the event spikes video/array
# Injecting event spikes found at 23218 locations in the frame
#
# Processing frame 349 of the event spikes video/array
# Injecting event spikes found at 23814 locations in the frame
#
# Processing frame 350 of the event spikes video/array
# Injecting event spikes found at 24405 locations in the frame
#
# Processing frame 351 of the event spikes video/array
# Injecting event spikes found at 25110 locations in the frame
#
# Processing frame 352 of the event spikes video/array
# Injecting event spikes found at 26246 locations in the frame
#
# Processing frame 353 of the event spikes video/array
# Injecting event spikes found at 26887 locations in the frame
#
# Processing frame 354 of the event spikes video/array
# Injecting event spikes found at 26680 locations in the frame
#
# Processing frame 355 of the event spikes video/array
# Injecting event spikes found at 27313 locations in the frame
#
# Processing frame 356 of the event spikes video/array
# Injecting event spikes found at 29138 locations in the frame
#
# Processing frame 357 of the event spikes video/array
# Injecting event spikes found at 30802 locations in the frame
#
# Processing frame 358 of the event spikes video/array
# Injecting event spikes found at 31128 locations in the frame
#
# Processing frame 359 of the event spikes video/array
# Injecting event spikes found at 30240 locations in the frame
#
# Processing frame 360 of the event spikes video/array
# Injecting event spikes found at 29853 locations in the frame
#
# Processing frame 361 of the event spikes video/array
# Injecting event spikes found at 28322 locations in the frame
#
# Processing frame 362 of the event spikes video/array
# Injecting event spikes found at 25037 locations in the frame
#
# Processing frame 363 of the event spikes video/array
# Injecting event spikes found at 23707 locations in the frame
#
# Processing frame 364 of the event spikes video/array
# Injecting event spikes found at 24850 locations in the frame
#
# Processing frame 365 of the event spikes video/array
# Injecting event spikes found at 24749 locations in the frame
#
# Processing frame 366 of the event spikes video/array
# Injecting event spikes found at 24880 locations in the frame
#
# Processing frame 367 of the event spikes video/array
# Injecting event spikes found at 24724 locations in the frame
#
# Processing frame 368 of the event spikes video/array
# Injecting event spikes found at 25942 locations in the frame
#
# Processing frame 369 of the event spikes video/array
# Injecting event spikes found at 28893 locations in the frame
#
# Processing frame 370 of the event spikes video/array
# Injecting event spikes found at 29375 locations in the frame
#
# Processing frame 371 of the event spikes video/array
# Injecting event spikes found at 31451 locations in the frame
#
# Processing frame 372 of the event spikes video/array
# Injecting event spikes found at 30399 locations in the frame
#
# Processing frame 373 of the event spikes video/array
# Injecting event spikes found at 24319 locations in the frame
#
# Processing frame 374 of the event spikes video/array
# Injecting event spikes found at 22792 locations in the frame
#
# Processing frame 375 of the event spikes video/array
# Injecting event spikes found at 25451 locations in the frame
#
# Processing frame 376 of the event spikes video/array
# Injecting event spikes found at 24379 locations in the frame
#
# Processing frame 377 of the event spikes video/array
# Injecting event spikes found at 24386 locations in the frame
#
# Processing frame 378 of the event spikes video/array
# Injecting event spikes found at 21728 locations in the frame
#
# Processing frame 379 of the event spikes video/array
# Injecting event spikes found at 19621 locations in the frame
#
# Processing frame 380 of the event spikes video/array
# Injecting event spikes found at 18262 locations in the frame
#
# Processing frame 381 of the event spikes video/array
# Injecting event spikes found at 16956 locations in the frame
#
# Processing frame 382 of the event spikes video/array
# Injecting event spikes found at 16414 locations in the frame
#
# Processing frame 383 of the event spikes video/array
# Injecting event spikes found at 16370 locations in the frame
#
# Processing frame 384 of the event spikes video/array
# Injecting event spikes found at 12347 locations in the frame
#
# Processing frame 385 of the event spikes video/array
# Injecting event spikes found at 15388 locations in the frame
#
# Processing frame 386 of the event spikes video/array
# Injecting event spikes found at 14866 locations in the frame
#
# Processing frame 387 of the event spikes video/array
# Injecting event spikes found at 13993 locations in the frame
#
# Processing frame 388 of the event spikes video/array
# Injecting event spikes found at 14185 locations in the frame
#
# Processing frame 389 of the event spikes video/array
# Injecting event spikes found at 14987 locations in the frame
#
# Processing frame 390 of the event spikes video/array
# Injecting event spikes found at 15361 locations in the frame
#
# Processing frame 391 of the event spikes video/array
# Injecting event spikes found at 12555 locations in the frame
#
# Processing frame 392 of the event spikes video/array
# Injecting event spikes found at 16640 locations in the frame
#
# Processing frame 393 of the event spikes video/array
# Injecting event spikes found at 16920 locations in the frame
#
# Processing frame 394 of the event spikes video/array
# Injecting event spikes found at 18365 locations in the frame
#
# Processing frame 395 of the event spikes video/array
# Injecting event spikes found at 21097 locations in the frame
#
# Processing frame 396 of the event spikes video/array
# Injecting event spikes found at 27412 locations in the frame
#
# Processing frame 397 of the event spikes video/array
# Injecting event spikes found at 203 locations in the frame
#
# Processing frame 398 of the event spikes video/array
# Injecting event spikes found at 227 locations in the frame
#
# Processing frame 399 of the event spikes video/array
# Injecting event spikes found at 69 locations in the frame
#
# Processing frame 400 of the event spikes video/array
# Injecting event spikes found at 388 locations in the frame
#
# Processing frame 401 of the event spikes video/array
# Injecting event spikes found at 207 locations in the frame
#
# Processing frame 402 of the event spikes video/array
# Injecting event spikes found at 177 locations in the frame
#
# Processing frame 403 of the event spikes video/array
# Injecting event spikes found at 146 locations in the frame
#
# Processing frame 404 of the event spikes video/array
# Injecting event spikes found at 282 locations in the frame
#
# Processing frame 405 of the event spikes video/array
# Injecting event spikes found at 1280 locations in the frame
#
# Processing frame 406 of the event spikes video/array
# Injecting event spikes found at 322 locations in the frame
#
# Processing frame 407 of the event spikes video/array
# Injecting event spikes found at 138 locations in the frame
#
# Processing frame 408 of the event spikes video/array
# Injecting event spikes found at 394 locations in the frame
#
# Processing frame 409 of the event spikes video/array
# Injecting event spikes found at 368 locations in the frame
#
# Processing frame 410 of the event spikes video/array
# Injecting event spikes found at 675 locations in the frame
#
# Processing frame 411 of the event spikes video/array
# Injecting event spikes found at 725 locations in the frame
#
# Processing frame 412 of the event spikes video/array
# Injecting event spikes found at 543 locations in the frame
#
# Processing frame 413 of the event spikes video/array
# Injecting event spikes found at 196 locations in the frame
#
# Processing frame 414 of the event spikes video/array
# Injecting event spikes found at 130 locations in the frame
#
# Processing frame 415 of the event spikes video/array
# Injecting event spikes found at 256 locations in the frame
#
# Processing frame 416 of the event spikes video/array
# Injecting event spikes found at 182 locations in the frame
#
# Processing frame 417 of the event spikes video/array
# Injecting event spikes found at 159 locations in the frame
#
# Processing frame 418 of the event spikes video/array
# Injecting event spikes found at 141 locations in the frame
#
# Processing frame 419 of the event spikes video/array
# Injecting event spikes found at 214 locations in the frame
#
# Processing frame 420 of the event spikes video/array
# ...
#
# Processing frame 2114 of the event spikes video/array
# Injecting event spikes found at 1350 locations in the frame
#
# Processing frame 2115 of the event spikes video/array
# Injecting event spikes found at 1234 locations in the frame
#
# Processing frame 2116 of the event spikes video/array
# Injecting event spikes found at 1434 locations in the frame
#
# Processing frame 2117 of the event spikes video/array
# Injecting event spikes found at 828 locations in the frame
#
# Processing frame 2118 of the event spikes video/array
# Injecting event spikes found at 891 locations in the frame
#
# Processing frame 2119 of the event spikes video/array
# Injecting event spikes found at 836 locations in the frame
#
# Processing frame 2120 of the event spikes video/array
# Injecting event spikes found at 908 locations in the frame
#
# Processing frame 2121 of the event spikes video/array
# Injecting event spikes found at 778 locations in the frame
#
# Processing frame 2122 of the event spikes video/array
# Injecting event spikes found at 890 locations in the frame
#
# Processing frame 2123 of the event spikes video/array
# Injecting event spikes found at 1008 locations in the frame
#
# Processing frame 2124 of the event spikes video/array
# Injecting event spikes found at 1227 locations in the frame
#
# Processing frame 2125 of the event spikes video/array
# Injecting event spikes found at 665 locations in the frame
#
# Processing frame 2126 of the event spikes video/array
# Injecting event spikes found at 730 locations in the frame
#
# Processing frame 2127 of the event spikes video/array
# Injecting event spikes found at 840 locations in the frame
#
# Processing frame 2128 of the event spikes video/array
# Injecting event spikes found at 610 locations in the frame
#
# Processing frame 2129 of the event spikes video/array
# Injecting event spikes found at 708 locations in the frame
#
# Processing frame 2130 of the event spikes video/array
# Injecting event spikes found at 622 locations in the frame
#
# Processing frame 2131 of the event spikes video/array
# Injecting event spikes found at 735 locations in the frame
#
# Processing frame 2132 of the event spikes video/array
# Injecting event spikes found at 760 locations in the frame
#
# Processing frame 2133 of the event spikes video/array
# Injecting event spikes found at 737 locations in the frame
#
# Processing frame 2134 of the event spikes video/array
# Injecting event spikes found at 712 locations in the frame
#
# Processing frame 2135 of the event spikes video/array
# Injecting event spikes found at 856 locations in the frame
#
# Processing frame 2136 of the event spikes video/array
# Injecting event spikes found at 1348 locations in the frame
#
# Processing frame 2137 of the event spikes video/array
# Injecting event spikes found at 722 locations in the frame
#
# Processing frame 2138 of the event spikes video/array
# Injecting event spikes found at 827 locations in the frame
#
# Processing frame 2139 of the event spikes video/array
# Injecting event spikes found at 919 locations in the frame
#
# Processing frame 2140 of the event spikes video/array
# Injecting event spikes found at 922 locations in the frame
#
# Processing frame 2141 of the event spikes video/array
# Injecting event spikes found at 920 locations in the frame
#
# Processing frame 2142 of the event spikes video/array
# Injecting event spikes found at 949 locations in the frame
#
# Processing frame 2143 of the event spikes video/array
# Injecting event spikes found at 1039 locations in the frame
#
# Processing frame 2144 of the event spikes video/array
# Injecting event spikes found at 903 locations in the frame
#
# Processing frame 2145 of the event spikes video/array
# Injecting event spikes found at 972 locations in the frame
#
# Processing frame 2146 of the event spikes video/array
# Injecting event spikes found at 1040 locations in the frame
#
# Processing frame 2147 of the event spikes video/array
# Injecting event spikes found at 55606 locations in the frame
#
# Processing frame 2148 of the event spikes video/array
# Injecting event spikes found at 31691 locations in the frame
#
# Processing frame 2149 of the event spikes video/array
# Injecting event spikes found at 30547 locations in the frame
#
# Processing frame 2150 of the event spikes video/array
# Injecting event spikes found at 30993 locations in the frame
#
# Processing frame 2151 of the event spikes video/array
# Injecting event spikes found at 29958 locations in the frame
#
# Processing frame 2152 of the event spikes video/array
# Injecting event spikes found at 26979 locations in the frame
#
# Processing frame 2153 of the event spikes video/array
# Injecting event spikes found at 22353 locations in the frame
#
# Processing frame 2154 of the event spikes video/array
# Injecting event spikes found at 18777 locations in the frame
#
# Processing frame 2155 of the event spikes video/array
# Injecting event spikes found at 22653 locations in the frame
#
# Processing frame 2156 of the event spikes video/array
# Injecting event spikes found at 27755 locations in the frame
#
# Processing frame 2157 of the event spikes video/array
# Injecting event spikes found at 31026 locations in the frame
#
# Processing frame 2158 of the event spikes video/array
# Injecting event spikes found at 28710 locations in the frame
#
# Processing frame 2159 of the event spikes video/array
# Injecting event spikes found at 25327 locations in the frame
#
# Processing frame 2160 of the event spikes video/array
# Injecting event spikes found at 26984 locations in the frame
#
# Processing frame 2161 of the event spikes video/array
# Injecting event spikes found at 23357 locations in the frame
#
# Processing frame 2162 of the event spikes video/array
# Injecting event spikes found at 18135 locations in the frame
#
# Processing frame 2163 of the event spikes video/array
# Injecting event spikes found at 19077 locations in the frame
#
# Processing frame 2164 of the event spikes video/array
# Injecting event spikes found at 14756 locations in the frame
#
# Processing frame 2165 of the event spikes video/array
# Injecting event spikes found at 14430 locations in the frame
#
# Processing frame 2166 of the event spikes video/array
# Injecting event spikes found at 9380 locations in the frame
#
# Processing frame 2167 of the event spikes video/array
# Injecting event spikes found at 8090 locations in the frame
#
# Processing frame 2168 of the event spikes video/array
# Injecting event spikes found at 9693 locations in the frame
#
# Processing frame 2169 of the event spikes video/array
# Injecting event spikes found at 6611 locations in the frame
#
# Processing frame 2170 of the event spikes video/array
# Injecting event spikes found at 8281 locations in the frame
#
# Processing frame 2171 of the event spikes video/array
# Injecting event spikes found at 12815 locations in the frame
#
# Processing frame 2172 of the event spikes video/array
# Injecting event spikes found at 11639 locations in the frame
#
# Processing frame 2173 of the event spikes video/array
# Injecting event spikes found at 7634 locations in the frame
#
# Processing frame 2174 of the event spikes video/array
# Injecting event spikes found at 12489 locations in the frame
#
# Processing frame 2175 of the event spikes video/array
# Injecting event spikes found at 13242 locations in the frame
#
# Processing frame 2176 of the event spikes video/array
# Injecting event spikes found at 10231 locations in the frame
#
# Processing frame 2177 of the event spikes video/array
# Injecting event spikes found at 6912 locations in the frame
#
# Processing frame 2178 of the event spikes video/array
# Injecting event spikes found at 7335 locations in the frame
#
# Processing frame 2179 of the event spikes video/array
# Injecting event spikes found at 9467 locations in the frame
#
# Processing frame 2180 of the event spikes video/array
# Injecting event spikes found at 10831 locations in the frame
#
# Processing frame 2181 of the event spikes video/array
# Injecting event spikes found at 12576 locations in the frame
#
# Processing frame 2182 of the event spikes video/array
# Injecting event spikes found at 10552 locations in the frame
#
# Processing frame 2183 of the event spikes video/array
# Injecting event spikes found at 8758 locations in the frame
#
# Processing frame 2184 of the event spikes video/array
# Injecting event spikes found at 10388 locations in the frame
#
# Processing frame 2185 of the event spikes video/array
# Injecting event spikes found at 12287 locations in the frame
#
# Processing frame 2186 of the event spikes video/array
# Injecting event spikes found at 11803 locations in the frame
#
# Processing frame 2187 of the event spikes video/array
# Injecting event spikes found at 10944 locations in the frame
#
# Processing frame 2188 of the event spikes video/array
# Injecting event spikes found at 13100 locations in the frame
#
# Processing frame 2189 of the event spikes video/array
# Injecting event spikes found at 17204 locations in the frame
#
# Processing frame 2190 of the event spikes video/array
# Injecting event spikes found at 18171 locations in the frame
#
# Processing frame 2191 of the event spikes video/array
# Injecting event spikes found at 17073 locations in the frame
#
# Processing frame 2192 of the event spikes video/array
# Injecting event spikes found at 14187 locations in the frame
#
# Processing frame 2193 of the event spikes video/array
# Injecting event spikes found at 15104 locations in the frame
#
# Processing frame 2194 of the event spikes video/array
# Injecting event spikes found at 13582 locations in the frame
#
# Processing frame 2195 of the event spikes video/array
# Injecting event spikes found at 9916 locations in the frame
#
# Processing frame 2196 of the event spikes video/array
# Injecting event spikes found at 5132 locations in the frame
#
# Processing frame 2197 of the event spikes video/array
# Injecting event spikes found at 1977 locations in the frame
#
# Processing frame 2198 of the event spikes video/array
# Injecting event spikes found at 2252 locations in the frame
#
# Processing frame 2199 of the event spikes video/array
# Injecting event spikes found at 1072 locations in the frame
#
# Processing frame 2200 of the event spikes video/array
# Injecting event spikes found at 1157 locations in the frame
#
# Processing frame 2201 of the event spikes video/array
# Injecting event spikes found at 1981 locations in the frame
#
# Processing frame 2202 of the event spikes video/array
# Injecting event spikes found at 1201 locations in the frame
#
# Processing frame 2203 of the event spikes video/array
# Injecting event spikes found at 1047 locations in the frame
#
# Processing frame 2204 of the event spikes video/array
# Injecting event spikes found at 1921 locations in the frame
#
# Processing frame 2205 of the event spikes video/array
# Injecting event spikes found at 1185 locations in the frame
#
# Processing frame 2206 of the event spikes video/array
# Injecting event spikes found at 1230 locations in the frame
#
# Processing frame 2207 of the event spikes video/array
# Injecting event spikes found at 1232 locations in the frame
#
# Processing frame 2208 of the event spikes video/array
# Injecting event spikes found at 1979 locations in the frame
#
# Processing frame 2209 of the event spikes video/array
# Injecting event spikes found at 1254 locations in the frame
#
# Processing frame 2210 of the event spikes video/array
# Injecting event spikes found at 1245 locations in the frame
#
# Processing frame 2211 of the event spikes video/array
# Injecting event spikes found at 2052 locations in the frame
#
# Processing frame 2212 of the event spikes video/array
# Injecting event spikes found at 1173 locations in the frame
#
# Processing frame 2213 of the event spikes video/array
# Injecting event spikes found at 1277 locations in the frame
#
# Processing frame 2214 of the event spikes video/array
# Injecting event spikes found at 1183 locations in the frame
#
# Processing frame 2215 of the event spikes video/array
# Injecting event spikes found at 1886 locations in the frame
#
# Processing frame 2216 of the event spikes video/array
# Injecting event spikes found at 1058 locations in the frame
#
# Processing frame 2217 of the event spikes video/array
# Injecting event spikes found at 1117 locations in the frame
#
# Processing frame 2218 of the event spikes video/array
# Injecting event spikes found at 1770 locations in the frame
#
# Processing frame 2219 of the event spikes video/array
# Injecting event spikes found at 1113 locations in the frame
#
# Processing frame 2220 of the event spikes video/array
# Injecting event spikes found at 1258 locations in the frame
#
# Processing frame 2221 of the event spikes video/array
# Injecting event spikes found at 1175 locations in the frame
#
# Processing frame 2222 of the event spikes video/array
# Injecting event spikes found at 1178 locations in the frame
#
# Processing frame 2223 of the event spikes video/array
# Injecting event spikes found at 1955 locations in the frame
#
# Processing frame 2224 of the event spikes video/array
# Injecting event spikes found at 1172 locations in the frame
#
# Processing frame 2225 of the event spikes video/array
# Injecting event spikes found at 1185 locations in the frame
#
# Processing frame 2226 of the event spikes video/array
# Injecting event spikes found at 1213 locations in the frame
#
# Processing frame 2227 of the event spikes video/array
# Injecting event spikes found at 1132 locations in the frame
#
# Processing frame 2228 of the event spikes video/array
# Injecting event spikes found at 1789 locations in the frame
#
# Processing frame 2229 of the event spikes video/array
# Injecting event spikes found at 994 locations in the frame
#
# Processing frame 2230 of the event spikes video/array
# Injecting event spikes found at 984 locations in the frame
#
# Processing frame 2231 of the event spikes video/array
# Injecting event spikes found at 1000 locations in the frame
#
# Processing frame 2232 of the event spikes video/array
# Injecting event spikes found at 1062 locations in the frame
#
# Processing frame 2233 of the event spikes video/array
# Injecting event spikes found at 1102 locations in the frame
#
# Processing frame 2234 of the event spikes video/array
# Injecting event spikes found at 1757 locations in the frame
#
# Processing frame 2235 of the event spikes video/array
# Injecting event spikes found at 1098 locations in the frame
#
# Processing frame 2236 of the event spikes video/array
# Injecting event spikes found at 1169 locations in the frame
#
# Processing frame 2237 of the event spikes video/array
# Injecting event spikes found at 1105 locations in the frame
#
# Processing frame 2238 of the event spikes video/array
# Injecting event spikes found at 1120 locations in the frame
#
# Processing frame 2239 of the event spikes video/array
# Injecting event spikes found at 1850 locations in the frame
#
# Processing frame 2240 of the event spikes video/array
# Injecting event spikes found at 1063 locations in the frame
#
# Processing frame 2241 of the event spikes video/array
# Injecting event spikes found at 1133 locations in the frame
#
# Processing frame 2242 of the event spikes video/array
# Injecting event spikes found at 1166 locations in the frame
#
# Processing frame 2243 of the event spikes video/array
# Injecting event spikes found at 1942 locations in the frame
#
# Processing frame 2244 of the event spikes video/array
# Injecting event spikes found at 1292 locations in the frame
#
# Processing frame 2245 of the event spikes video/array
# Injecting event spikes found at 1203 locations in the frame
#
# Processing frame 2246 of the event spikes video/array
# Injecting event spikes found at 1315 locations in the frame
#
# Processing frame 2247 of the event spikes video/array
# Injecting event spikes found at 2016 locations in the frame
#
# Processing frame 2248 of the event spikes video/array
# Injecting event spikes found at 1348 locations in the frame
#
# Processing frame 2249 of the event spikes video/array
# Injecting event spikes found at 1331 locations in the frame
#
# Processing frame 2250 of the event spikes video/array
# Injecting event spikes found at 1442 locations in the frame
#
# Injected 25327032 events into the event data
#
# Saving event data with specified event spikes injected to ../projection/data/20220112_jpt_floating_kth_screwdriver/0002/event.h5

# %% [markdown]
# ### Project object spikes and save to video

# %%
# OpenCV colours

white = (255, 255, 255)
blue = (255, 0, 0)
green = (0, 255, 0)
red = (0, 0, 255)
yellow = (0, 255, 255)
grey = (50, 50, 50)

# %%
def get_next_event(events_iter, camera):
    event = {}
    event[f'timestamp_{camera}'] = next(events_iter[f'timestamp_{camera}'])
    event[f'polarity_{camera}'] = next(events_iter[f'polarity_{camera}'])
    event[f'xy_undistorted_{camera}'] = next(events_iter[f'xy_undistorted_{camera}'])
    event[f'label_{camera}'] = next(events_iter[f'label_{camera}'])

    return event


def get_next_pose(poses_iter, n_cameras):
    pose = {}

    pose['timestamp'] = next(
        poses_iter['timestamp'])

    pose['rotation'] = {}
    for prop_name in poses_iter['rotation'].keys():
        pose['rotation'][prop_name] = next(
            poses_iter['rotation'][prop_name])

    for i in range(n_cameras):
        pose[f'camera_{i}_rotation'] = {}
        for prop_name in poses_iter[f'camera_{i}_rotation'].keys():
            pose[f'camera_{i}_rotation'][prop_name] = next(
                poses_iter[f'camera_{i}_rotation'][prop_name])

    pose['translation'] = {}
    for prop_name in poses_iter['translation'].keys():
        pose['translation'][prop_name] = next(
            poses_iter['translation'][prop_name])

    for i in range(n_cameras):
        pose[f'camera_{i}_translation'] = {}
        for prop_name in poses_iter[f'camera_{i}_translation'].keys():
            pose[f'camera_{i}_translation'][prop_name] = next(
                poses_iter[f'camera_{i}_translation'][prop_name])

    return pose

# %%
def projection(data_path, output_video_path, max_frames=500, fps=25):

    n_cameras = 1
    # n_cameras = 2
    event_distinguish_polarity = False

    dvs_cam_height = [np.uint32(260) for i in range(n_cameras)]
    dvs_cam_width = [np.uint32(346) for i in range(n_cameras)]
    dvs_cam_origin_x_offset = [dvs_cam_width[i] / 2 for i in range(n_cameras)]
    dvs_cam_origin_y_offset = [dvs_cam_height[i] / 2 for i in range(n_cameras)]
    dvs_cam_nominal_f_len = [4.0 for i in range(n_cameras)]
    dvs_cam_pixel_mm = [1.8e-2 for i in range(n_cameras)]

    # Read recording info from JSON
    with open(f'{data_path}/info.json', 'r') as info_json_file:
        info_json = json.load(info_json_file)

    ##################################################################

    # === READ PROPS DATA ===
    props_markers = {}    # contains the translation of each marker, relative to prop origin
    props_meshes = {}     # contains prop STL meshes (polygon, translation, vertex)
    props_labels = {}     # contains integer > 0 class labels of the props
    props_dilation = {}   # contains dilation kernels for the mask of each prop

    props_names = list(info_json['prop_marker_files'].keys())
    for prop_name in props_names:
        with open(info_json['prop_marker_files'][prop_name], 'r') as marker_file:
            markers = json.load(marker_file)
        props_markers[prop_name] = markers
        mesh = stl.mesh.Mesh.from_file(info_json['prop_mesh_files'][prop_name]).vectors.transpose(0, 2, 1)
        props_meshes[prop_name] = mesh
        props_labels[prop_name] = info_json['prop_labels'][prop_name]
        props_dilation[prop_name] = np.ones((3, 3), 'uint8')

    # Change prop mask dilation
    #props_dilation['kth_hammer'] = np.ones((4, 4), 'uint8')
    #props_dilation['kth_screwdriver'] = np.ones((4, 4), 'uint8')
    #props_dilation['kth_spanner'] = np.ones((4, 4), 'uint8')

    ##################################################################

    # === READ CALIBRATION FILES ===

    path_projection = info_json['projection_calibration_path']

    v_to_dvs_rotation_file = [f'{path_projection}/v_to_dv_{i}_rotation.npy' for i in range(n_cameras)]
    v_to_dvs_rotation = [np.load(name) for name in v_to_dvs_rotation_file]

    v_to_dvs_translation_file = [f'{path_projection}/v_to_dv_{i}_translation.npy' for i in range(n_cameras)]
    v_to_dvs_translation = [np.load(name) for name in v_to_dvs_translation_file]

    v_to_dvs_f_len_scale_file = [f'{path_projection}/v_to_dv_{i}_focal_length_scale.npy' for i in range(n_cameras)]
    v_to_dvs_f_len_scale = [np.load(name) for name in v_to_dvs_f_len_scale_file]
    v_to_dvs_f_len = [dvs_cam_nominal_f_len[i] * v_to_dvs_f_len_scale[i] for i in range(n_cameras)]

    v_to_dvs_x_scale_file = [f'{path_projection}/v_to_dv_{i}_x_scale.npy' for i in range(n_cameras)]
    v_to_dvs_x_scale = [np.load(name) for name in v_to_dvs_x_scale_file]

    ##################################################################



    # initialise temp memory
    event_pos = [np.zeros((dvs_cam_height[i], dvs_cam_width[i]), dtype='uint64') for i in range(n_cameras)]
    event_neg = [np.zeros((dvs_cam_height[i], dvs_cam_width[i]), dtype='uint64') for i in range(n_cameras)]
    event_image = [np.zeros((dvs_cam_height[i], dvs_cam_width[i], 3), dtype='uint8') for i in range(n_cameras)]
    prop_masks = [{prop_name: np.empty((dvs_cam_height[i], dvs_cam_width[i]), dtype='uint8')
                   for prop_name in props_names} for i in range(n_cameras)]

    events_vid = np.zeros((1, dvs_cam_height[0], dvs_cam_width[0], 3), dtype='uint8')

    # load DVS event data
    events_file_name = f'{data_path}/event.h5'
    events_file = tables.open_file(events_file_name, mode='r')
    events_iter = []
    for i in range(n_cameras):
        e_iter = {}
        e_iter[f'timestamp_{i}'] = events_file.root[f'timestamp_{i}'].iterrows()
        e_iter[f'polarity_{i}'] = events_file.root[f'polarity_{i}'].iterrows()
        e_iter[f'xy_undistorted_{i}'] = events_file.root[f'xy_undistorted_{i}'].iterrows()
        e_iter[f'label_{i}'] = events_file.root[f'label_{i}'].iterrows()
        events_iter.append(e_iter)

    event = [get_next_event(events_iter[i], i) for i in range(n_cameras)]

    # load Vicon pose data file
    poses_file_name = f'{data_path}/pose.h5'
    poses_file = tables.open_file(poses_file_name, mode='r')
    poses_iter = {}

    timestamp = poses_file.root.timestamp
    poses_iter['timestamp'] = timestamp.iterrows()

    poses_iter['rotation'] = {}
    for i in range(n_cameras):
        poses_iter[f'camera_{i}_rotation'] = {}

    poses_iter['translation'] = {}
    for i in range(n_cameras):
        poses_iter[f'camera_{i}_translation'] = {}

    for prop_name in props_names:
        rotation = poses_file.root.props[prop_name].rotation
        poses_iter['rotation'][prop_name] = rotation.iterrows()
        for i in range(n_cameras):
            cam_rotation = poses_file.root.props[prop_name][f'camera_{i}_rotation']
            poses_iter[f'camera_{i}_rotation'][prop_name] = cam_rotation.iterrows()

        translation = poses_file.root.props[prop_name].translation
        poses_iter['translation'][prop_name] = translation.iterrows()
        for i in range(n_cameras):
            cam_translation = poses_file.root.props[prop_name][f'camera_{i}_translation']
            poses_iter[f'camera_{i}_translation'][prop_name] = cam_translation.iterrows()

    pose = get_next_pose(poses_iter, n_cameras)

    # === MAIN LOOP ===
    
    frames_count = 0

    done_event = [False for i in range(n_cameras)]
    while not all(done_event):

        try:
            pose_new = get_next_pose(poses_iter, n_cameras)
            pose_midway = pose['timestamp'] / 2 + pose_new['timestamp'] / 2
        except StopIteration:
            print('DEBUG: out of Vicon poses')
            break

        frames_count += 1
        if frames_count > max_frames:
            break

        # print()
        # print('Vicon pose timestamp: ', pose['timestamp'])
        print(f"Processing frame {frames_count}")

        for prop_name in props_names:

            # compute prop mask for each camera
            for i in range(n_cameras):
                prop_masks[i][prop_name].fill(0)

                mesh_to_dvs_rotation = pose[f'camera_{i}_rotation'][prop_name]
                mesh_to_dvs_translation = pose[f'camera_{i}_translation'][prop_name]

                if not np.isfinite(mesh_to_dvs_rotation).all() or not np.isfinite(mesh_to_dvs_translation).all():
                    continue

                # transform to DVS camera space
                dvs_space_p = np.matmul(mesh_to_dvs_rotation, props_meshes[prop_name]) + mesh_to_dvs_translation
                dvs_space_p[:, :2, :] *= (1 / dvs_space_p[:, np.newaxis, 2, :])
                dvs_space_p = dvs_space_p[:, :2, :]
                dvs_space_p *= v_to_dvs_f_len[i]
                dvs_space_p /= dvs_cam_pixel_mm[i]
                dvs_space_p *= v_to_dvs_x_scale[i]
                dvs_space_p += [[dvs_cam_origin_x_offset[i]], [dvs_cam_origin_y_offset[i]]]
                dvs_space_p_int = np.rint(dvs_space_p).astype('int32')

                # transpose points for OpenCV
                dvs_space_p_int = dvs_space_p_int.transpose(0, 2, 1)

                # compute prop mask
                cv2.fillPoly(prop_masks[i][prop_name], dvs_space_p_int, 255)
                prop_masks[i][prop_name] = cv2.dilate(prop_masks[i][prop_name], props_dilation[prop_name])


        # process DVS events
        for i in range(n_cameras):
            if not done_event[i]:

                image = event_image[i]
                pos = event_pos[i]
                neg = event_neg[i]

                image.fill(0)
                pos.fill(0)
                neg.fill(0)

                while event[i][f'timestamp_{i}'] < pose_midway:
                    xy_int = np.rint(event[i][f'xy_undistorted_{i}']).astype('int32')

                    if event[i][f'polarity_{i}']:
                        pos[xy_int[1], xy_int[0]] += 1
                    else:
                        neg[xy_int[1], xy_int[0]] += 1

                    if event_distinguish_polarity:
                        if event[i][f'polarity_{i}']:
                            image[xy_int[1], xy_int[0]] = white # red
                        else:
                            image[xy_int[1], xy_int[0]] = white # green
                    else:
                        image[xy_int[1], xy_int[0]] = white # green


                    # get event label
                    label = event[i][f'label_{i}']

                    try:
                        event[i] = get_next_event(events_iter[i], i)
                    except StopIteration:
                        print(f'DEBUG: out of DVS {i} events')
                        done_event[i] = True
                        break

                # fill DVS event image with events, then mask it
                for prop_name in props_names:
                    # TODO: FIXME: image[mask] = grey will overwrite events from other props
                    mask = prop_masks[i][prop_name].astype('bool')
                    image[mask] = grey # show prop mask?
                    if event_distinguish_polarity:
                        mask_neg = neg > pos
                        image[(mask_neg & mask)] = blue
                        mask_pos = pos > neg
                        image[(mask_pos & mask)] = yellow
                    else:
                        mask_pos_neg = neg.astype('bool') | pos.astype('bool')
                        image[(mask_pos_neg & mask)] = red

                img = image.copy()
                img = np.expand_dims(img, axis=0)        
                events_vid = np.vstack((events_vid, img))


        pose = pose_new


    array_to_video(events_vid, output_video_path, fps)

    # cleanup
    events_file.close()
    poses_file.close()

# %%
# Switch to directory containing data

# %cd ../projection
# !ls
# Out:
# /home/neelay/projects/gsoc/projection
# camera_calibration    gen_aug_images.py       props
# custom_projection.py  inject.py		      tinker.ipynb
# data		      projection_calibration  tmp

# %%
data_path = "data/20220112_jpt_floating_kth_screwdriver/0002/"

# Should contain:
# - event.h5 (with event injected from the previous step)
# - pose.h5
# - info.json

# The other data files containing translation data, rotation data, etc. should be present
# as per the info (paths) in the info.json file.

# %%
projection(
    data_path=data_path,
    output_video_path="../event_aug/tmp/augmented_event.mp4",
    max_frames=600,
    fps=30,
)
# Out:
# Processing frame 1
# Processing frame 2
# Processing frame 3
# Processing frame 4
# Processing frame 5
# Processing frame 6
# Processing frame 7
# Processing frame 8
# Processing frame 9
# Processing frame 10
# Processing frame 11
# Processing frame 12
# Processing frame 13
# Processing frame 14
# Processing frame 15
# Processing frame 16
# Processing frame 17
# Processing frame 18
# Processing frame 19
# Processing frame 20
# Processing frame 21
# Processing frame 22
# Processing frame 23
# Processing frame 24
# Processing frame 25
# Processing frame 26
# Processing frame 27
# Processing frame 28
# Processing frame 29
# Processing frame 30
# Processing frame 31
# Processing frame 32
# Processing frame 33
# Processing frame 34
# Processing frame 35
# Processing frame 36
# Processing frame 37
# Processing frame 38
# Processing frame 39
# Processing frame 40
# Processing frame 41
# Processing frame 42
# Processing frame 43
# Processing frame 44
# Processing frame 45
# Processing frame 46
# Processing frame 47
# Processing frame 48
# Processing frame 49
# Processing frame 50
# Processing frame 51
# Processing frame 52
# Processing frame 53
# Processing frame 54
# Processing frame 55
# Processing frame 56
# Processing frame 57
# Processing frame 58
# Processing frame 59
# Processing frame 60
# Processing frame 61
# Processing frame 62
# Processing frame 63
# Processing frame 64
# Processing frame 65
# Processing frame 66
# Processing frame 67
# Processing frame 68
# Processing frame 69
# Processing frame 70
# Processing frame 71
# Processing frame 72
# Processing frame 73
# Processing frame 74
# Processing frame 75
# Processing frame 76
# Processing frame 77
# Processing frame 78
# Processing frame 79
# Processing frame 80
# Processing frame 81
# Processing frame 82
# Processing frame 83
# Processing frame 84
# Processing frame 85
# Processing frame 86
# Processing frame 87
# Processing frame 88
# Processing frame 89
# Processing frame 90
# Processing frame 91
# Processing frame 92
# Processing frame 93
# Processing frame 94
# Processing frame 95
# Processing frame 96
# Processing frame 97
# Processing frame 98
# Processing frame 99
# Processing frame 100
# Processing frame 101
# Processing frame 102
# Processing frame 103
# Processing frame 104
# Processing frame 105
# Processing frame 106
# Processing frame 107
# Processing frame 108
# Processing frame 109
# Processing frame 110
# Processing frame 111
# Processing frame 112
# Processing frame 113
# Processing frame 114
# Processing frame 115
# Processing frame 116
# Processing frame 117
# Processing frame 118
# Processing frame 119
# Processing frame 120
# Processing frame 121
# Processing frame 122
# Processing frame 123
# Processing frame 124
# Processing frame 125
# Processing frame 126
# Processing frame 127
# Processing frame 128
# Processing frame 129
# Processing frame 130
# Processing frame 131
# Processing frame 132
# Processing frame 133
# Processing frame 134
# Processing frame 135
# Processing frame 136
# Processing frame 137
# Processing frame 138
# Processing frame 139
# Processing frame 140
# Processing frame 141
# Processing frame 142
# Processing frame 143
# Processing frame 144
# Processing frame 145
# Processing frame 146
# Processing frame 147
# Processing frame 148
# Processing frame 149
# Processing frame 150
# Processing frame 151
# Processing frame 152
# Processing frame 153
# Processing frame 154
# Processing frame 155
# Processing frame 156
# Processing frame 157
# Processing frame 158
# Processing frame 159
# Processing frame 160
# Processing frame 161
# Processing frame 162
# Processing frame 163
# Processing frame 164
# Processing frame 165
# Processing frame 166
# Processing frame 167
# Processing frame 168
# Processing frame 169
# Processing frame 170
# Processing frame 171
# Processing frame 172
# Processing frame 173
# Processing frame 174
# Processing frame 175
# Processing frame 176
# Processing frame 177
# Processing frame 178
# Processing frame 179
# Processing frame 180
# Processing frame 181
# Processing frame 182
# Processing frame 183
# Processing frame 184
# Processing frame 185
# Processing frame 186
# Processing frame 187
# Processing frame 188
# Processing frame 189
# Processing frame 190
# Processing frame 191
# Processing frame 192
# Processing frame 193
# Processing frame 194
# Processing frame 195
# Processing frame 196
# Processing frame 197
# Processing frame 198
# Processing frame 199
# Processing frame 200
# Processing frame 201
# Processing frame 202
# Processing frame 203
# Processing frame 204
# Processing frame 205
# Processing frame 206
# Processing frame 207
# Processing frame 208
# Processing frame 209
# Processing frame 210
# Processing frame 211
# Processing frame 212
# Processing frame 213
# Processing frame 214
# Processing frame 215
# Processing frame 216
# Processing frame 217
# Processing frame 218
# Processing frame 219
# Processing frame 220
# Processing frame 221
# Processing frame 222
# Processing frame 223
# Processing frame 224
# Processing frame 225
# Processing frame 226
# Processing frame 227
# Processing frame 228
# Processing frame 229
# Processing frame 230
# Processing frame 231
# Processing frame 232
# Processing frame 233
# Processing frame 234
# Processing frame 235
# Processing frame 236
# Processing frame 237
# Processing frame 238
# Processing frame 239
# Processing frame 240
# Processing frame 241
# Processing frame 242
# Processing frame 243
# Processing frame 244
# Processing frame 245
# Processing frame 246
# Processing frame 247
# Processing frame 248
# Processing frame 249
# Processing frame 250
# Processing frame 251
# Processing frame 252
# Processing frame 253
# Processing frame 254
# Processing frame 255
# Processing frame 256
# Processing frame 257
# Processing frame 258
# Processing frame 259
# Processing frame 260
# Processing frame 261
# Processing frame 262
# Processing frame 263
# Processing frame 264
# Processing frame 265
# Processing frame 266
# Processing frame 267
# Processing frame 268
# Processing frame 269
# Processing frame 270
# Processing frame 271
# Processing frame 272
# Processing frame 273
# Processing frame 274
# Processing frame 275
# Processing frame 276
# Processing frame 277
# Processing frame 278
# Processing frame 279
# Processing frame 280
# Processing frame 281
# Processing frame 282
# Processing frame 283
# Processing frame 284
# Processing frame 285
# Processing frame 286
# Processing frame 287
# Processing frame 288
# Processing frame 289
# Processing frame 290
# Processing frame 291
# Processing frame 292
# Processing frame 293
# Processing frame 294
# Processing frame 295
# Processing frame 296
# Processing frame 297
# Processing frame 298
# Processing frame 299
# Processing frame 300
# Processing frame 301
# Processing frame 302
# Processing frame 303
# Processing frame 304
# Processing frame 305
# Processing frame 306
# Processing frame 307
# Processing frame 308
# Processing frame 309
# Processing frame 310
# Processing frame 311
# Processing frame 312
# Processing frame 313
# Processing frame 314
# Processing frame 315
# Processing frame 316
# Processing frame 317
# Processing frame 318
# Processing frame 319
# Processing frame 320
# Processing frame 321
# Processing frame 322
# Processing frame 323
# Processing frame 324
# Processing frame 325
# Processing frame 326
# Processing frame 327
# Processing frame 328
# Processing frame 329
# Processing frame 330
# Processing frame 331
# Processing frame 332
# Processing frame 333
# Processing frame 334
# Processing frame 335
# Processing frame 336
# Processing frame 337
# Processing frame 338
# Processing frame 339
# Processing frame 340
# Processing frame 341
# Processing frame 342
# Processing frame 343
# Processing frame 344
# Processing frame 345
# Processing frame 346
# Processing frame 347
# Processing frame 348
# Processing frame 349
# Processing frame 350
# Processing frame 351
# Processing frame 352
# Processing frame 353
# Processing frame 354
# Processing frame 355
# Processing frame 356
# Processing frame 357
# Processing frame 358
# Processing frame 359
# Processing frame 360
# Processing frame 361
# Processing frame 362
# Processing frame 363
# Processing frame 364
# Processing frame 365
# Processing frame 366
# Processing frame 367
# Processing frame 368
# Processing frame 369
# Processing frame 370
# Processing frame 371
# Processing frame 372
# Processing frame 373
# Processing frame 374
# Processing frame 375
# Processing frame 376
# Processing frame 377
# Processing frame 378
# Processing frame 379
# Processing frame 380
# Processing frame 381
# Processing frame 382
# Processing frame 383
# Processing frame 384
# Processing frame 385
# Processing frame 386
# Processing frame 387
# Processing frame 388
# Processing frame 389
# Processing frame 390
# Processing frame 391
# Processing frame 392
# Processing frame 393
# Processing frame 394
# Processing frame 395
# Processing frame 396
# Processing frame 397
# Processing frame 398
# Processing frame 399
# Processing frame 400
# Processing frame 401
# Processing frame 402
# Processing frame 403
# Processing frame 404
# Processing frame 405
# Processing frame 406
# Processing frame 407
# Processing frame 408
# Processing frame 409
# Processing frame 410
# Processing frame 411
# Processing frame 412
# Processing frame 413
# Processing frame 414
# Processing frame 415
# Processing frame 416
# Processing frame 417
# Processing frame 418
# Processing frame 419
# Processing frame 420
# Processing frame 421
# Processing frame 422
# Processing frame 423
# Processing frame 424
# Processing frame 425
# Processing frame 426
# Processing frame 427
# Processing frame 428
# Processing frame 429
# Processing frame 430
# Processing frame 431
# Processing frame 432
# Processing frame 433
# Processing frame 434
# Processing frame 435
# Processing frame 436
# Processing frame 437
# Processing frame 438
# Processing frame 439
# Processing frame 440
# Processing frame 441
# Processing frame 442
# Processing frame 443
# Processing frame 444
# Processing frame 445
# Processing frame 446
# Processing frame 447
# Processing frame 448
# Processing frame 449
# Processing frame 450
# Processing frame 451
# Processing frame 452
# Processing frame 453
# Processing frame 454
# Processing frame 455
# Processing frame 456
# Processing frame 457
# Processing frame 458
# Processing frame 459
# Processing frame 460
# Processing frame 461
# Processing frame 462
# Processing frame 463
# Processing frame 464
# Processing frame 465
# Processing frame 466
# Processing frame 467
# Processing frame 468
# Processing frame 469
# Processing frame 470
# Processing frame 471
# Processing frame 472
# Processing frame 473
# Processing frame 474
# Processing frame 475
# Processing frame 476
# Processing frame 477
# Processing frame 478
# Processing frame 479
# Processing frame 480
# Processing frame 481
# Processing frame 482
# Processing frame 483
# Processing frame 484
# Processing frame 485
# Processing frame 486
# Processing frame 487
# Processing frame 488
# Processing frame 489
# Processing frame 490
# Processing frame 491
# Processing frame 492
# Processing frame 493
# Processing frame 494
# Processing frame 495
# Processing frame 496
# Processing frame 497
# Processing frame 498
# Processing frame 499
# Processing frame 500
# Processing frame 501
# Processing frame 502
# Processing frame 503
# Processing frame 504
# Processing frame 505
# Processing frame 506
# Processing frame 507
# Processing frame 508
# Processing frame 509
# Processing frame 510
# Processing frame 511
# Processing frame 512
# Processing frame 513
# Processing frame 514
# Processing frame 515
# Processing frame 516
# Processing frame 517
# Processing frame 518
# Processing frame 519
# Processing frame 520
# Processing frame 521
# Processing frame 522
# Processing frame 523
# Processing frame 524
# Processing frame 525
# Processing frame 526
# Processing frame 527
# Processing frame 528
# Processing frame 529
# Processing frame 530
# Processing frame 531
# Processing frame 532
# Processing frame 533
# Processing frame 534
# Processing frame 535
# Processing frame 536
# Processing frame 537
# Processing frame 538
# Processing frame 539
# Processing frame 540
# Processing frame 541
# Processing frame 542
# Processing frame 543
# Processing frame 544
# Processing frame 545
# Processing frame 546
# Processing frame 547
# Processing frame 548
# Processing frame 549
# Processing frame 550
# Processing frame 551
# Processing frame 552
# Processing frame 553
# Processing frame 554
# Processing frame 555
# Processing frame 556
# Processing frame 557
# Processing frame 558
# Processing frame 559
# Processing frame 560
# Processing frame 561
# Processing frame 562
# Processing frame 563
# Processing frame 564
# Processing frame 565
# Processing frame 566
# Processing frame 567
# Processing frame 568
# Processing frame 569
# Processing frame 570
# Processing frame 571
# Processing frame 572
# Processing frame 573
# Processing frame 574
# Processing frame 575
# Processing frame 576
# Processing frame 577
# Processing frame 578
# Processing frame 579
# Processing frame 580
# Processing frame 581
# Processing frame 582
# Processing frame 583
# Processing frame 584
# Processing frame 585
# Processing frame 586
# Processing frame 587
# Processing frame 588
# Processing frame 589
# Processing frame 590
# Processing frame 591
# Processing frame 592
# Processing frame 593
# Processing frame 594
# Processing frame 595
# Processing frame 596
# Processing frame 597
# Processing frame 598
# Processing frame 599
# Processing frame 600
# Frame width: 346, Frame height: 260, FPS: 30
