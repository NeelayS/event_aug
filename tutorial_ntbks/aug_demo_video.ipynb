# %% [markdown]
# Install the `event_aug` package according to the instructions in the README.

# %%
from event_aug.spike_encoding import delta_intensity_code_video
from event_aug.spike_injection import inject_event_spikes
from event_aug.utils import download_from_youtube, resize_video

# %%
import os

# %%
from projection import projection

# %%
WORKING_DIR = "tmp"
os.makedirs(WORKING_DIR, exist_ok=True)

# %% [markdown]
# ### Download video from YouTube

# %%
download_from_youtube(
    ["https://www.youtube.com/watch?v=cbL9NV-dStU"],
    start_times=[20],
    end_times=[110],
    save_dir=WORKING_DIR,
)
# Out:
# Downloading video 1 of 1
# ffmpeg version 4.2.2 Copyright (c) 2000-2019 the FFmpeg developers
#   built with gcc 7.3.0 (crosstool-NG 1.23.0.449-a04d0)
#   configuration: --prefix=/home/neelay/miniconda3 --cc=/tmp/build/80754af9/ffmpeg_1587154242452/_build_env/bin/x86_64-conda_cos6-linux-gnu-cc --disable-doc --enable-avresample --enable-gmp --enable-hardcoded-tables --enable-libfreetype --enable-libvpx --enable-pthreads --enable-libopus --enable-postproc --enable-pic --enable-pthreads --enable-shared --enable-static --enable-version3 --enable-zlib --enable-libmp3lame --disable-nonfree --enable-gpl --enable-gnutls --disable-openssl --enable-libopenh264 --enable-libx264
#   libavutil      56. 31.100 / 56. 31.100
#   libavcodec     58. 54.100 / 58. 54.100
#   libavformat    58. 29.100 / 58. 29.100
#   libavdevice    58.  8.100 / 58.  8.100
#   libavfilter     7. 57.100 /  7. 57.100
#   libavresample   4.  0.  0 /  4.  0.  0
#   libswscale      5.  5.100 /  5.  5.100
#   libswresample   3.  5.100 /  3.  5.100
#   libpostproc    55.  5.100 / 55.  5.100
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from 'https://rr2---sn-4g5ednz7.googlevideo.com/videoplayback?expire=1662599368&ei=aOwYY-LfJ52A8gPB6ZVg&ip=78.43.40.2&id=o-AHOmfWIyb1xoCcpjIiiVfMNlJtF3FyLhvz41lzFl1Mki&itag=137&aitags=133%2C134%2C135%2C136%2C137%2C160%2C242%2C243%2C244%2C247%2C248%2C278%2C394%2C395%2C396%2C397%2C398%2C399&source=youtube&requiressl=yes&mh=qd&mm=31%2C26&mn=sn-4g5ednz7%2Csn-i5h7lner&ms=au%2Conr&mv=m&mvi=2&pl=21&initcwndbps=1473750&vprv=1&mime=video%2Fmp4&ns=YfYgeJVrDq5xc4e5M-SVNaIH&gir=yes&clen=54334889&dur=136.320&lmt=1659951706582963&mt=1662577283&fvip=5&keepalive=yes&fexp=24001373%2C24007246&c=WEB&rbqsm=fr&txp=5535434&n=ZI5_6sKStIxADNBH56LFe&sparams=expire%2Cei%2Cip%2Cid%2Caitags%2Csource%2Crequiressl%2Cvprv%2Cmime%2Cns%2Cgir%2Cclen%2Cdur%2Clmt&sig=AOq0QJ8wRAIgClIMfS1P4Ea0vcz8vjFJFGrz2ZKGNC0vQ3rUUzAk67ACIEzV1juGFxuusoBPZcEh6YvnXqB_CqbPrlnQcOP15soj&lsparams=mh%2Cmm%2Cmn%2Cms%2Cmv%2Cmvi%2Cpl%2Cinitcwndbps&lsig=AG3C_xAwRgIhAKjBzRAchylIF6CKGhFDewQ5CnWi4ksW5_0JKX9gurpzAiEA1jikn6_jyofCGhKD7y2BAU0wGC7JZCSqpexuigMkJp0%3D':
#   Metadata:
#     major_brand     : dash
#     minor_version   : 0
#     compatible_brands: iso6avc1mp41
#     creation_time   : 2022-08-08T09:29:39.000000Z
#   Duration: 00:02:16.32, start: 0.000000, bitrate: 3188 kb/s
#     Stream #0:0(und): Video: h264 (High) (avc1 / 0x31637661), yuv420p(tv, bt709, progressive), 1920x1080 [SAR 1:1 DAR 16:9], 93 kb/s, 25 fps, 25 tbr, 12800 tbn, 50 tbc (default)
#     Metadata:
#       creation_time   : 2022-08-08T09:29:39.000000Z
#       handler_name    : ISO Media file produced by Google Inc.
# Input #1, mov,mp4,m4a,3gp,3g2,mj2, from 'https://rr2---sn-4g5ednz7.googlevideo.com/videoplayback?expire=1662599368&ei=aOwYY-LfJ52A8gPB6ZVg&ip=78.43.40.2&id=o-AHOmfWIyb1xoCcpjIiiVfMNlJtF3FyLhvz41lzFl1Mki&itag=140&source=youtube&requiressl=yes&mh=qd&mm=31%2C26&mn=sn-4g5ednz7%2Csn-i5h7lner&ms=au%2Conr&mv=m&mvi=2&pl=21&initcwndbps=1473750&vprv=1&mime=audio%2Fmp4&ns=YfYgeJVrDq5xc4e5M-SVNaIH&gir=yes&clen=2207712&dur=136.370&lmt=1659948656625513&mt=1662577283&fvip=5&keepalive=yes&fexp=24001373%2C24007246&c=WEB&rbqsm=fr&txp=5532434&n=ZI5_6sKStIxADNBH56LFe&sparams=expire%2Cei%2Cip%2Cid%2Citag%2Csource%2Crequiressl%2Cvprv%2Cmime%2Cns%2Cgir%2Cclen%2Cdur%2Clmt&sig=AOq0QJ8wRQIgGrErc7F5t1ILcp-pHvlQ7VlpDhQSXF9EWNehMV45hbECIQC3h3EL8c0_hnUAhZOVZiohBL6Lf0MzzTvFZkL_H-auWw%3D%3D&lsparams=mh%2Cmm%2Cmn%2Cms%2Cmv%2Cmvi%2Cpl%2Cinitcwndbps&lsig=AG3C_xAwRgIhAKjBzRAchylIF6CKGhFDewQ5CnWi4ksW5_0JKX9gurpzAiEA1jikn6_jyofCGhKD7y2BAU0wGC7JZCSqpexuigMkJp0%3D':
#   Metadata:
#     major_brand     : dash
#     minor_version   : 0
#     compatible_brands: iso6mp41
#     creation_time   : 2022-08-08T08:48:25.000000Z
#   Duration: 00:02:16.37, start: 0.000000, bitrate: 129 kb/s
#     Stream #1:0(eng): Audio: aac (LC) (mp4a / 0x6134706D), 44100 Hz, stereo, fltp, 9 kb/s (default)
#     Metadata:
#       creation_time   : 2022-08-08T08:48:25.000000Z
#       handler_name    : ISO Media file produced by Google Inc.
# Output #0, mp4, to 'tmp/0.mp4':
#   Metadata:
#     major_brand     : dash
#     minor_version   : 0
#     compatible_brands: iso6avc1mp41
#     encoder         : Lavf58.29.100
#     Stream #0:0(und): Video: h264 (High) (avc1 / 0x31637661), yuv420p(tv, bt709, progressive), 1920x1080 [SAR 1:1 DAR 16:9], q=2-31, 93 kb/s, 25 fps, 25 tbr, 12800 tbn, 12800 tbc (default)
#     Metadata:
#       creation_time   : 2022-08-08T09:29:39.000000Z
#       handler_name    : ISO Media file produced by Google Inc.
#     Stream #0:1(eng): Audio: aac (LC) (mp4a / 0x6134706D), 44100 Hz, stereo, fltp, 9 kb/s (default)
#     Metadata:
#       creation_time   : 2022-08-08T08:48:25.000000Z
#       handler_name    : ISO Media file produced by Google Inc.
# Stream mapping:
#   Stream #0:0 -> #0:0 (copy)
#   Stream #1:0 -> #0:1 (copy)
# Press [q] to stop, [?] for help
# frame= 2337 fps=2.8 q=-1.0 Lsize=   42041kB time=00:01:29.99 bitrate=3826.9kbits/s speed=0.107x
# video:40562kB audio:1407kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.172568%

# %% [markdown]
# ### Resize video to camera resolution

# %%
# Optional

resize_video(
    "tmp/0.mp4",
    "tmp/0_resized.mp4",
    size=(346, 260),
)

# %% [markdown]
# ### Convert video to spikes

# %%
spikes = delta_intensity_code_video(
    "tmp/0_resized.mp4",
    percent_threshold=25,
    mode="percent_threshold",
    exclude_start=True,
    return_arr=False,
    save_video=True,
    video_save_path="tmp/encoded_vid_0.mp4",
    save_arr=True,
    arr_save_path="tmp/encoded_vid_0.npy",
)
# Out:
# Frame width: 346, Frame height: 260, Input FPS: 25, Output FPS: 25, Number of frames: 2501

# %% [markdown]
# ### Inject spikes into existing event sequence

# %%
event_file_path = "./data/event_data/event.h5"
save_path = "./data/event_data/augmented_event.h5"

# %%
augmentation_events_label = 2

inject_event_spikes(
    event_file_path,
    save_path,
    spikes_arr="tmp/encoded_vid_0.npy", # spikes
    spikes_arr_from_file=True, # False
    memory_map=True, # False
    fps=400,
    label=augmentation_events_label,
    polarity=1,
    resize_size=(346, 260), # None
    verbose=True,
)
# Out:
# Processing frame 0 of the event spikes video/array
# Injecting event spikes found at 0 locations in the frame
#
# Processing frame 1 of the event spikes video/array
# Injecting event spikes found at 45027 locations in the frame
#
# Processing frame 2 of the event spikes video/array
# Injecting event spikes found at 34507 locations in the frame
#
# Processing frame 3 of the event spikes video/array
# Injecting event spikes found at 24332 locations in the frame
#
# Processing frame 4 of the event spikes video/array
# Injecting event spikes found at 9492 locations in the frame
#
# Processing frame 5 of the event spikes video/array
# Injecting event spikes found at 6317 locations in the frame
#
# Processing frame 6 of the event spikes video/array
# Injecting event spikes found at 5803 locations in the frame
#
# Processing frame 7 of the event spikes video/array
# Injecting event spikes found at 5780 locations in the frame
#
# Processing frame 8 of the event spikes video/array
# Injecting event spikes found at 5723 locations in the frame
#
# Processing frame 9 of the event spikes video/array
# Injecting event spikes found at 5498 locations in the frame
#
# Processing frame 10 of the event spikes video/array
# Injecting event spikes found at 5530 locations in the frame
#
# Processing frame 11 of the event spikes video/array
# Injecting event spikes found at 5772 locations in the frame
#
# Processing frame 12 of the event spikes video/array
# Injecting event spikes found at 6037 locations in the frame
#
# Processing frame 13 of the event spikes video/array
# Injecting event spikes found at 6482 locations in the frame
#
# Processing frame 14 of the event spikes video/array
# Injecting event spikes found at 6416 locations in the frame
#
# Processing frame 15 of the event spikes video/array
# Injecting event spikes found at 6262 locations in the frame
#
# Processing frame 16 of the event spikes video/array
# Injecting event spikes found at 6346 locations in the frame
#
# Processing frame 17 of the event spikes video/array
# Injecting event spikes found at 6440 locations in the frame
#
# Processing frame 18 of the event spikes video/array
# Injecting event spikes found at 6294 locations in the frame
#
# Processing frame 19 of the event spikes video/array
# Injecting event spikes found at 6259 locations in the frame
#
# Processing frame 20 of the event spikes video/array
# Injecting event spikes found at 6356 locations in the frame
#
# Processing frame 21 of the event spikes video/array
# Injecting event spikes found at 6218 locations in the frame
#
# Processing frame 22 of the event spikes video/array
# Injecting event spikes found at 6208 locations in the frame
#
# Processing frame 23 of the event spikes video/array
# Injecting event spikes found at 6038 locations in the frame
#
# Processing frame 24 of the event spikes video/array
# Injecting event spikes found at 6304 locations in the frame
#
# Processing frame 25 of the event spikes video/array
# Injecting event spikes found at 6450 locations in the frame
#
# Processing frame 26 of the event spikes video/array
# Injecting event spikes found at 5662 locations in the frame
#
# Processing frame 27 of the event spikes video/array
# Injecting event spikes found at 5502 locations in the frame
#
# Processing frame 28 of the event spikes video/array
# Injecting event spikes found at 5388 locations in the frame
#
# Processing frame 29 of the event spikes video/array
# Injecting event spikes found at 5531 locations in the frame
#
# Processing frame 30 of the event spikes video/array
# Injecting event spikes found at 5295 locations in the frame
#
# Processing frame 31 of the event spikes video/array
# Injecting event spikes found at 5494 locations in the frame
#
# Processing frame 32 of the event spikes video/array
# Injecting event spikes found at 5284 locations in the frame
#
# Processing frame 33 of the event spikes video/array
# Injecting event spikes found at 5534 locations in the frame
#
# Processing frame 34 of the event spikes video/array
# Injecting event spikes found at 5302 locations in the frame
#
# Processing frame 35 of the event spikes video/array
# Injecting event spikes found at 5354 locations in the frame
#
# Processing frame 36 of the event spikes video/array
# Injecting event spikes found at 5629 locations in the frame
#
# Processing frame 37 of the event spikes video/array
# Injecting event spikes found at 5361 locations in the frame
#
# Processing frame 38 of the event spikes video/array
# Injecting event spikes found at 5435 locations in the frame
#
# Processing frame 39 of the event spikes video/array
# Injecting event spikes found at 55934 locations in the frame
#
# Processing frame 40 of the event spikes video/array
# Injecting event spikes found at 35720 locations in the frame
#
# Processing frame 41 of the event spikes video/array
# Injecting event spikes found at 35154 locations in the frame
#
# Processing frame 42 of the event spikes video/array
# Injecting event spikes found at 34592 locations in the frame
#
# Processing frame 43 of the event spikes video/array
# Injecting event spikes found at 35390 locations in the frame
#
# Processing frame 44 of the event spikes video/array
# Injecting event spikes found at 35553 locations in the frame
#
# Processing frame 45 of the event spikes video/array
# Injecting event spikes found at 35811 locations in the frame
#
# Processing frame 46 of the event spikes video/array
# Injecting event spikes found at 36434 locations in the frame
#
# Processing frame 47 of the event spikes video/array
# Injecting event spikes found at 36512 locations in the frame
#
# Processing frame 48 of the event spikes video/array
# Injecting event spikes found at 36953 locations in the frame
#
# Processing frame 49 of the event spikes video/array
# Injecting event spikes found at 36534 locations in the frame
#
# Processing frame 50 of the event spikes video/array
# Injecting event spikes found at 36494 locations in the frame
#
# Processing frame 51 of the event spikes video/array
# Injecting event spikes found at 36516 locations in the frame
#
# Processing frame 52 of the event spikes video/array
# Injecting event spikes found at 36895 locations in the frame
#
# Processing frame 53 of the event spikes video/array
# Injecting event spikes found at 37761 locations in the frame
#
# Processing frame 54 of the event spikes video/array
# Injecting event spikes found at 38084 locations in the frame
#
# Processing frame 55 of the event spikes video/array
# Injecting event spikes found at 37551 locations in the frame
#
# Processing frame 56 of the event spikes video/array
# Injecting event spikes found at 37603 locations in the frame
#
# Processing frame 57 of the event spikes video/array
# Injecting event spikes found at 37772 locations in the frame
#
# Processing frame 58 of the event spikes video/array
# Injecting event spikes found at 37978 locations in the frame
#
# Processing frame 59 of the event spikes video/array
# Injecting event spikes found at 37775 locations in the frame
#
# Processing frame 60 of the event spikes video/array
# Injecting event spikes found at 38871 locations in the frame
#
# Processing frame 61 of the event spikes video/array
# Injecting event spikes found at 38029 locations in the frame
#
# Processing frame 62 of the event spikes video/array
# Injecting event spikes found at 38601 locations in the frame
#
# Processing frame 63 of the event spikes video/array
# Injecting event spikes found at 37966 locations in the frame
#
# Processing frame 64 of the event spikes video/array
# Injecting event spikes found at 37496 locations in the frame
#
# Processing frame 65 of the event spikes video/array
# Injecting event spikes found at 37502 locations in the frame
#
# Processing frame 66 of the event spikes video/array
# Injecting event spikes found at 37399 locations in the frame
#
# Processing frame 67 of the event spikes video/array
# Injecting event spikes found at 37953 locations in the frame
#
# Processing frame 68 of the event spikes video/array
# Injecting event spikes found at 37495 locations in the frame
#
# Processing frame 69 of the event spikes video/array
# Injecting event spikes found at 37274 locations in the frame
#
# Processing frame 70 of the event spikes video/array
# Injecting event spikes found at 38067 locations in the frame
#
# Processing frame 71 of the event spikes video/array
# Injecting event spikes found at 37948 locations in the frame
#
# Processing frame 72 of the event spikes video/array
# Injecting event spikes found at 38714 locations in the frame
#
# Processing frame 73 of the event spikes video/array
# Injecting event spikes found at 37903 locations in the frame
#
# Processing frame 74 of the event spikes video/array
# Injecting event spikes found at 37421 locations in the frame
#
# Processing frame 75 of the event spikes video/array
# Injecting event spikes found at 37433 locations in the frame
#
# Processing frame 76 of the event spikes video/array
# Injecting event spikes found at 36795 locations in the frame
#
# Processing frame 77 of the event spikes video/array
# Injecting event spikes found at 35871 locations in the frame
#
# Processing frame 78 of the event spikes video/array
# Injecting event spikes found at 34874 locations in the frame
#
# Processing frame 79 of the event spikes video/array
# Injecting event spikes found at 33788 locations in the frame
#
# Processing frame 80 of the event spikes video/array
# Injecting event spikes found at 33067 locations in the frame
#
# Processing frame 81 of the event spikes video/array
# Injecting event spikes found at 32738 locations in the frame
#
# Processing frame 82 of the event spikes video/array
# Injecting event spikes found at 33331 locations in the frame
#
# Processing frame 83 of the event spikes video/array
# Injecting event spikes found at 33066 locations in the frame
#
# Processing frame 84 of the event spikes video/array
# Injecting event spikes found at 34860 locations in the frame
#
# Processing frame 85 of the event spikes video/array
# Injecting event spikes found at 34674 locations in the frame
#
# Processing frame 86 of the event spikes video/array
# Injecting event spikes found at 33863 locations in the frame
#
# Processing frame 87 of the event spikes video/array
# Injecting event spikes found at 35118 locations in the frame
#
# Processing frame 88 of the event spikes video/array
# Injecting event spikes found at 35139 locations in the frame
#
# Processing frame 89 of the event spikes video/array
# Injecting event spikes found at 34635 locations in the frame
#
# Processing frame 90 of the event spikes video/array
# Injecting event spikes found at 33325 locations in the frame
#
# Processing frame 91 of the event spikes video/array
# Injecting event spikes found at 28930 locations in the frame
#
# Processing frame 92 of the event spikes video/array
# Injecting event spikes found at 18427 locations in the frame
#
# Processing frame 93 of the event spikes video/array
# Injecting event spikes found at 16378 locations in the frame
#
# Processing frame 94 of the event spikes video/array
# Injecting event spikes found at 17665 locations in the frame
#
# Processing frame 95 of the event spikes video/array
# Injecting event spikes found at 14852 locations in the frame
#
# Processing frame 96 of the event spikes video/array
# Injecting event spikes found at 18381 locations in the frame
#
# Processing frame 97 of the event spikes video/array
# Injecting event spikes found at 16605 locations in the frame
#
# Processing frame 98 of the event spikes video/array
# Injecting event spikes found at 17419 locations in the frame
#
# Processing frame 99 of the event spikes video/array
# Injecting event spikes found at 18049 locations in the frame
#
# Processing frame 100 of the event spikes video/array
# Injecting event spikes found at 18607 locations in the frame
#
# Processing frame 101 of the event spikes video/array
# Injecting event spikes found at 17905 locations in the frame
#
# Processing frame 102 of the event spikes video/array
# Injecting event spikes found at 18988 locations in the frame
#
# Processing frame 103 of the event spikes video/array
# Injecting event spikes found at 24128 locations in the frame
#
# Processing frame 104 of the event spikes video/array
# Injecting event spikes found at 27496 locations in the frame
#
# Processing frame 105 of the event spikes video/array
# Injecting event spikes found at 59224 locations in the frame
#
# Processing frame 106 of the event spikes video/array
# Injecting event spikes found at 5066 locations in the frame
#
# Processing frame 107 of the event spikes video/array
# Injecting event spikes found at 5198 locations in the frame
#
# Processing frame 108 of the event spikes video/array
# Injecting event spikes found at 6675 locations in the frame
#
# Processing frame 109 of the event spikes video/array
# Injecting event spikes found at 7308 locations in the frame
#
# Processing frame 110 of the event spikes video/array
# Injecting event spikes found at 7858 locations in the frame
#
# Processing frame 111 of the event spikes video/array
# Injecting event spikes found at 7951 locations in the frame
#
# Processing frame 112 of the event spikes video/array
# Injecting event spikes found at 7989 locations in the frame
#
# Processing frame 113 of the event spikes video/array
# Injecting event spikes found at 8134 locations in the frame
#
# Processing frame 114 of the event spikes video/array
# Injecting event spikes found at 8270 locations in the frame
#
# Processing frame 115 of the event spikes video/array
# Injecting event spikes found at 8636 locations in the frame
#
# Processing frame 116 of the event spikes video/array
# Injecting event spikes found at 8947 locations in the frame
#
# Processing frame 117 of the event spikes video/array
# Injecting event spikes found at 9465 locations in the frame
#
# Processing frame 118 of the event spikes video/array
# Injecting event spikes found at 9541 locations in the frame
#
# Processing frame 119 of the event spikes video/array
# Injecting event spikes found at 9665 locations in the frame
#
# Processing frame 120 of the event spikes video/array
# Injecting event spikes found at 9790 locations in the frame
#
# Processing frame 121 of the event spikes video/array
# Injecting event spikes found at 10022 locations in the frame
#
# Processing frame 122 of the event spikes video/array
# Injecting event spikes found at 10182 locations in the frame
#
# Processing frame 123 of the event spikes video/array
# Injecting event spikes found at 10142 locations in the frame
#
# Processing frame 124 of the event spikes video/array
# Injecting event spikes found at 10265 locations in the frame
#
# Processing frame 125 of the event spikes video/array
# Injecting event spikes found at 10340 locations in the frame
#
# Processing frame 126 of the event spikes video/array
# Injecting event spikes found at 10368 locations in the frame
#
# Processing frame 127 of the event spikes video/array
# Injecting event spikes found at 10265 locations in the frame
#
# Processing frame 128 of the event spikes video/array
# Injecting event spikes found at 10469 locations in the frame
#
# Processing frame 129 of the event spikes video/array
# Injecting event spikes found at 10734 locations in the frame
#
# Processing frame 130 of the event spikes video/array
# Injecting event spikes found at 10443 locations in the frame
#
# Processing frame 131 of the event spikes video/array
# Injecting event spikes found at 10152 locations in the frame
#
# Processing frame 132 of the event spikes video/array
# Injecting event spikes found at 10225 locations in the frame
#
# Processing frame 133 of the event spikes video/array
# Injecting event spikes found at 9813 locations in the frame
#
# Processing frame 134 of the event spikes video/array
# Injecting event spikes found at 9743 locations in the frame
#
# Processing frame 135 of the event spikes video/array
# Injecting event spikes found at 9459 locations in the frame
#
# Processing frame 136 of the event spikes video/array
# Injecting event spikes found at 9556 locations in the frame
#
# Processing frame 137 of the event spikes video/array
# Injecting event spikes found at 9241 locations in the frame
#
# Processing frame 138 of the event spikes video/array
# Injecting event spikes found at 9299 locations in the frame
#
# Processing frame 139 of the event spikes video/array
# Injecting event spikes found at 9319 locations in the frame
#
# Processing frame 140 of the event spikes video/array
# Injecting event spikes found at 9248 locations in the frame
#
# Processing frame 141 of the event spikes video/array
# Injecting event spikes found at 9965 locations in the frame
#
# Processing frame 142 of the event spikes video/array
# Injecting event spikes found at 9569 locations in the frame
#
# Processing frame 143 of the event spikes video/array
# Injecting event spikes found at 9105 locations in the frame
#
# Processing frame 144 of the event spikes video/array
# Injecting event spikes found at 9031 locations in the frame
#
# Processing frame 145 of the event spikes video/array
# Injecting event spikes found at 9235 locations in the frame
#
# Processing frame 146 of the event spikes video/array
# Injecting event spikes found at 9005 locations in the frame
#
# Processing frame 147 of the event spikes video/array
# Injecting event spikes found at 8505 locations in the frame
#
# Processing frame 148 of the event spikes video/array
# Injecting event spikes found at 8039 locations in the frame
#
# Processing frame 149 of the event spikes video/array
# Injecting event spikes found at 7942 locations in the frame
#
# Processing frame 150 of the event spikes video/array
# Injecting event spikes found at 7907 locations in the frame
#
# Processing frame 151 of the event spikes video/array
# Injecting event spikes found at 8069 locations in the frame
#
# Processing frame 152 of the event spikes video/array
# Injecting event spikes found at 8136 locations in the frame
#
# Processing frame 153 of the event spikes video/array
# Injecting event spikes found at 7698 locations in the frame
#
# Processing frame 154 of the event spikes video/array
# Injecting event spikes found at 7568 locations in the frame
#
# Processing frame 155 of the event spikes video/array
# Injecting event spikes found at 8665 locations in the frame
#
# Processing frame 156 of the event spikes video/array
# Injecting event spikes found at 7812 locations in the frame
#
# Processing frame 157 of the event spikes video/array
# Injecting event spikes found at 8467 locations in the frame
#
# Processing frame 158 of the event spikes video/array
# Injecting event spikes found at 8141 locations in the frame
#
# Processing frame 159 of the event spikes video/array
# Injecting event spikes found at 7416 locations in the frame
#
# Processing frame 160 of the event spikes video/array
# Injecting event spikes found at 7561 locations in the frame
#
# Processing frame 161 of the event spikes video/array
# Injecting event spikes found at 7092 locations in the frame
#
# Processing frame 162 of the event spikes video/array
# Injecting event spikes found at 7394 locations in the frame
#
# Processing frame 163 of the event spikes video/array
# Injecting event spikes found at 7320 locations in the frame
#
# Processing frame 164 of the event spikes video/array
# Injecting event spikes found at 7591 locations in the frame
#
# Processing frame 165 of the event spikes video/array
# Injecting event spikes found at 8593 locations in the frame
#
# Processing frame 166 of the event spikes video/array
# Injecting event spikes found at 9260 locations in the frame
#
# Processing frame 167 of the event spikes video/array
# Injecting event spikes found at 9522 locations in the frame
#
# Processing frame 168 of the event spikes video/array
# Injecting event spikes found at 9401 locations in the frame
#
# Processing frame 169 of the event spikes video/array
# Injecting event spikes found at 9423 locations in the frame
#
# Processing frame 170 of the event spikes video/array
# Injecting event spikes found at 9246 locations in the frame
#
# Processing frame 171 of the event spikes video/array
# Injecting event spikes found at 9236 locations in the frame
#
# Processing frame 172 of the event spikes video/array
# Injecting event spikes found at 8416 locations in the frame
#
# Processing frame 173 of the event spikes video/array
# Injecting event spikes found at 8050 locations in the frame
#
# Processing frame 174 of the event spikes video/array
# Injecting event spikes found at 7740 locations in the frame
#
# Processing frame 175 of the event spikes video/array
# Injecting event spikes found at 6998 locations in the frame
#
# Processing frame 176 of the event spikes video/array
# Injecting event spikes found at 6703 locations in the frame
#
# Processing frame 177 of the event spikes video/array
# Injecting event spikes found at 6759 locations in the frame
#
# Processing frame 178 of the event spikes video/array
# Injecting event spikes found at 6480 locations in the frame
#
# Processing frame 179 of the event spikes video/array
# Injecting event spikes found at 7243 locations in the frame
#
# Processing frame 180 of the event spikes video/array
# Injecting event spikes found at 6444 locations in the frame
#
# Processing frame 181 of the event spikes video/array
# Injecting event spikes found at 3018 locations in the frame
#
# Processing frame 182 of the event spikes video/array
# Injecting event spikes found at 1697 locations in the frame
#
# Processing frame 183 of the event spikes video/array
# Injecting event spikes found at 2431 locations in the frame
#
# Processing frame 184 of the event spikes video/array
# Injecting event spikes found at 2896 locations in the frame
#
# Processing frame 185 of the event spikes video/array
# Injecting event spikes found at 5451 locations in the frame
#
# Processing frame 186 of the event spikes video/array
# Injecting event spikes found at 6797 locations in the frame
#
# Processing frame 187 of the event spikes video/array
# Injecting event spikes found at 7880 locations in the frame
#
# Processing frame 188 of the event spikes video/array
# Injecting event spikes found at 9099 locations in the frame
#
# Processing frame 189 of the event spikes video/array
# Injecting event spikes found at 10288 locations in the frame
#
# Processing frame 190 of the event spikes video/array
# Injecting event spikes found at 11537 locations in the frame
#
# Processing frame 191 of the event spikes video/array
# Injecting event spikes found at 11931 locations in the frame
#
# Processing frame 192 of the event spikes video/array
# Injecting event spikes found at 11970 locations in the frame
#
# Processing frame 193 of the event spikes video/array
# Injecting event spikes found at 11624 locations in the frame
#
# Processing frame 194 of the event spikes video/array
# Injecting event spikes found at 10232 locations in the frame
#
# Processing frame 195 of the event spikes video/array
# Injecting event spikes found at 8800 locations in the frame
#
# Processing frame 196 of the event spikes video/array
# Injecting event spikes found at 8011 locations in the frame
#
# Processing frame 197 of the event spikes video/array
# Injecting event spikes found at 6375 locations in the frame
#
# Processing frame 198 of the event spikes video/array
# Injecting event spikes found at 5290 locations in the frame
#
# Processing frame 199 of the event spikes video/array
# Injecting event spikes found at 4846 locations in the frame
#
# Processing frame 200 of the event spikes video/array
# Injecting event spikes found at 5326 locations in the frame
#
# Processing frame 201 of the event spikes video/array
# Injecting event spikes found at 5145 locations in the frame
#
# Processing frame 202 of the event spikes video/array
# Injecting event spikes found at 3047 locations in the frame
#
# Processing frame 203 of the event spikes video/array
# Injecting event spikes found at 4832 locations in the frame
#
# Processing frame 204 of the event spikes video/array
# Injecting event spikes found at 5725 locations in the frame
#
# Processing frame 205 of the event spikes video/array
# Injecting event spikes found at 6855 locations in the frame
#
# Processing frame 206 of the event spikes video/array
# Injecting event spikes found at 7735 locations in the frame
#
# Processing frame 207 of the event spikes video/array
# Injecting event spikes found at 8441 locations in the frame
#
# Processing frame 208 of the event spikes video/array
# Injecting event spikes found at 8899 locations in the frame
#
# Processing frame 209 of the event spikes video/array
# Injecting event spikes found at 8766 locations in the frame
#
# Processing frame 210 of the event spikes video/array
# Injecting event spikes found at 7117 locations in the frame
#
# Processing frame 211 of the event spikes video/array
# Injecting event spikes found at 4705 locations in the frame
#
# Processing frame 212 of the event spikes video/array
# Injecting event spikes found at 2634 locations in the frame
#
# Processing frame 213 of the event spikes video/array
# Injecting event spikes found at 2609 locations in the frame
#
# Processing frame 214 of the event spikes video/array
# Injecting event spikes found at 2067 locations in the frame
#
# Processing frame 215 of the event spikes video/array
# Injecting event spikes found at 2998 locations in the frame
#
# Processing frame 216 of the event spikes video/array
# Injecting event spikes found at 3102 locations in the frame
#
# Processing frame 217 of the event spikes video/array
# Injecting event spikes found at 4032 locations in the frame
#
# Processing frame 218 of the event spikes video/array
# Injecting event spikes found at 3807 locations in the frame
#
# Processing frame 219 of the event spikes video/array
# Injecting event spikes found at 3406 locations in the frame
#
# Processing frame 220 of the event spikes video/array
# Injecting event spikes found at 5192 locations in the frame
#
# Processing frame 221 of the event spikes video/array
# Injecting event spikes found at 4500 locations in the frame
#
# Processing frame 222 of the event spikes video/array
# Injecting event spikes found at 4203 locations in the frame
#
# Processing frame 223 of the event spikes video/array
# Injecting event spikes found at 4852 locations in the frame
#
# Processing frame 224 of the event spikes video/array
# Injecting event spikes found at 3842 locations in the frame
#
# Processing frame 225 of the event spikes video/array
# Injecting event spikes found at 4542 locations in the frame
#
# Processing frame 226 of the event spikes video/array
# Injecting event spikes found at 3432 locations in the frame
#
# Processing frame 227 of the event spikes video/array
# Injecting event spikes found at 4395 locations in the frame
#
# Processing frame 228 of the event spikes video/array
# Injecting event spikes found at 3022 locations in the frame
#
# Processing frame 229 of the event spikes video/array
# Injecting event spikes found at 2890 locations in the frame
#
# Processing frame 230 of the event spikes video/array
# Injecting event spikes found at 3256 locations in the frame
#
# Processing frame 231 of the event spikes video/array
# Injecting event spikes found at 3165 locations in the frame
#
# Processing frame 232 of the event spikes video/array
# Injecting event spikes found at 2719 locations in the frame
#
# Processing frame 233 of the event spikes video/array
# Injecting event spikes found at 2073 locations in the frame
#
# Processing frame 234 of the event spikes video/array
# Injecting event spikes found at 1209 locations in the frame
#
# Processing frame 235 of the event spikes video/array
# Injecting event spikes found at 1140 locations in the frame
#
# Processing frame 236 of the event spikes video/array
# Injecting event spikes found at 750 locations in the frame
#
# Processing frame 237 of the event spikes video/array
# Injecting event spikes found at 1364 locations in the frame
#
# Processing frame 238 of the event spikes video/array
# Injecting event spikes found at 754 locations in the frame
#
# Processing frame 239 of the event spikes video/array
# Injecting event spikes found at 873 locations in the frame
#
# Processing frame 240 of the event spikes video/array
# Injecting event spikes found at 948 locations in the frame
#
# Processing frame 241 of the event spikes video/array
# Injecting event spikes found at 825 locations in the frame
#
# Processing frame 242 of the event spikes video/array
# Injecting event spikes found at 1007 locations in the frame
#
# Processing frame 243 of the event spikes video/array
# Injecting event spikes found at 804 locations in the frame
#
# Processing frame 244 of the event spikes video/array
# Injecting event spikes found at 743 locations in the frame
#
# Processing frame 245 of the event spikes video/array
# Injecting event spikes found at 790 locations in the frame
#
# Processing frame 246 of the event spikes video/array
# Injecting event spikes found at 1059 locations in the frame
#
# Processing frame 247 of the event spikes video/array
# Injecting event spikes found at 744 locations in the frame
#
# Processing frame 248 of the event spikes video/array
# Injecting event spikes found at 787 locations in the frame
#
# Processing frame 249 of the event spikes video/array
# Injecting event spikes found at 2659 locations in the frame
#
# Processing frame 250 of the event spikes video/array
# Injecting event spikes found at 2556 locations in the frame
#
# Processing frame 251 of the event spikes video/array
# Injecting event spikes found at 2364 locations in the frame
#
# Processing frame 252 of the event spikes video/array
# Injecting event spikes found at 1538 locations in the frame
#
# Processing frame 253 of the event spikes video/array
# Injecting event spikes found at 1258 locations in the frame
#
# Processing frame 254 of the event spikes video/array
# Injecting event spikes found at 664 locations in the frame
#
# Processing frame 255 of the event spikes video/array
# Injecting event spikes found at 685 locations in the frame
#
# Processing frame 256 of the event spikes video/array
# Injecting event spikes found at 959 locations in the frame
#
# Processing frame 257 of the event spikes video/array
# Injecting event spikes found at 1461 locations in the frame
#
# Processing frame 258 of the event spikes video/array
# Injecting event spikes found at 748 locations in the frame
#
# Processing frame 259 of the event spikes video/array
# Injecting event spikes found at 707 locations in the frame
#
# Processing frame 260 of the event spikes video/array
# Injecting event spikes found at 670 locations in the frame
#
# Processing frame 261 of the event spikes video/array
# Injecting event spikes found at 2750 locations in the frame
#
# Processing frame 262 of the event spikes video/array
# Injecting event spikes found at 1791 locations in the frame
#
# Processing frame 263 of the event spikes video/array
# Injecting event spikes found at 70657 locations in the frame
#
# Processing frame 264 of the event spikes video/array
# Injecting event spikes found at 31643 locations in the frame
#
# Processing frame 265 of the event spikes video/array
# Injecting event spikes found at 27376 locations in the frame
#
# Processing frame 266 of the event spikes video/array
# Injecting event spikes found at 51865 locations in the frame
#
# Processing frame 267 of the event spikes video/array
# Injecting event spikes found at 28679 locations in the frame
#
# Processing frame 268 of the event spikes video/array
# Injecting event spikes found at 60137 locations in the frame
#
# Processing frame 269 of the event spikes video/array
# Injecting event spikes found at 50773 locations in the frame
#
# Processing frame 270 of the event spikes video/array
# Injecting event spikes found at 50503 locations in the frame
#
# Processing frame 271 of the event spikes video/array
# Injecting event spikes found at 41015 locations in the frame
#
# Processing frame 272 of the event spikes video/array
# Injecting event spikes found at 37487 locations in the frame
#
# Processing frame 273 of the event spikes video/array
# Injecting event spikes found at 42183 locations in the frame
#
# Processing frame 274 of the event spikes video/array
# Injecting event spikes found at 42150 locations in the frame
#
# Processing frame 275 of the event spikes video/array
# Injecting event spikes found at 39784 locations in the frame
#
# Processing frame 276 of the event spikes video/array
# Injecting event spikes found at 48804 locations in the frame
#
# Processing frame 277 of the event spikes video/array
# Injecting event spikes found at 55810 locations in the frame
#
# Processing frame 278 of the event spikes video/array
# Injecting event spikes found at 50306 locations in the frame
#
# Processing frame 279 of the event spikes video/array
# Injecting event spikes found at 10118 locations in the frame
#
# Processing frame 280 of the event spikes video/array
# Injecting event spikes found at 10036 locations in the frame
#
# Processing frame 281 of the event spikes video/array
# Injecting event spikes found at 8918 locations in the frame
#
# Processing frame 282 of the event spikes video/array
# Injecting event spikes found at 10658 locations in the frame
#
# Processing frame 283 of the event spikes video/array
# Injecting event spikes found at 10740 locations in the frame
#
# Processing frame 284 of the event spikes video/array
# Injecting event spikes found at 10181 locations in the frame
#
# Processing frame 285 of the event spikes video/array
# Injecting event spikes found at 11518 locations in the frame
#
# Processing frame 286 of the event spikes video/array
# Injecting event spikes found at 12849 locations in the frame
#
# Processing frame 287 of the event spikes video/array
# Injecting event spikes found at 12811 locations in the frame
#
# Processing frame 288 of the event spikes video/array
# Injecting event spikes found at 12229 locations in the frame
#
# Processing frame 289 of the event spikes video/array
# Injecting event spikes found at 15261 locations in the frame
#
# Processing frame 290 of the event spikes video/array
# Injecting event spikes found at 18366 locations in the frame
#
# Processing frame 291 of the event spikes video/array
# Injecting event spikes found at 19075 locations in the frame
#
# Processing frame 292 of the event spikes video/array
# Injecting event spikes found at 13885 locations in the frame
#
# Processing frame 293 of the event spikes video/array
# Injecting event spikes found at 12472 locations in the frame
#
# Processing frame 294 of the event spikes video/array
# Injecting event spikes found at 17773 locations in the frame
#
# Processing frame 295 of the event spikes video/array
# Injecting event spikes found at 19327 locations in the frame
#
# Processing frame 296 of the event spikes video/array
# Injecting event spikes found at 16981 locations in the frame
#
# Processing frame 297 of the event spikes video/array
# Injecting event spikes found at 14196 locations in the frame
#
# Processing frame 298 of the event spikes video/array
# Injecting event spikes found at 9861 locations in the frame
#
# Processing frame 299 of the event spikes video/array
# Injecting event spikes found at 14050 locations in the frame
#
# Processing frame 300 of the event spikes video/array
# Injecting event spikes found at 11967 locations in the frame
#
# Processing frame 301 of the event spikes video/array
# Injecting event spikes found at 10238 locations in the frame
#
# Processing frame 302 of the event spikes video/array
# Injecting event spikes found at 14324 locations in the frame
#
# Processing frame 303 of the event spikes video/array
# Injecting event spikes found at 16662 locations in the frame
#
# Processing frame 304 of the event spikes video/array
# Injecting event spikes found at 15308 locations in the frame
#
# Processing frame 305 of the event spikes video/array
# Injecting event spikes found at 17642 locations in the frame
#
# Processing frame 306 of the event spikes video/array
# Injecting event spikes found at 17999 locations in the frame
#
# Processing frame 307 of the event spikes video/array
# Injecting event spikes found at 25685 locations in the frame
#
# Processing frame 308 of the event spikes video/array
# Injecting event spikes found at 30180 locations in the frame
#
# Processing frame 309 of the event spikes video/array
# Injecting event spikes found at 33195 locations in the frame
#
# Processing frame 310 of the event spikes video/array
# Injecting event spikes found at 33531 locations in the frame
#
# Processing frame 311 of the event spikes video/array
# Injecting event spikes found at 33162 locations in the frame
#
# Processing frame 312 of the event spikes video/array
# Injecting event spikes found at 36850 locations in the frame
#
# Processing frame 313 of the event spikes video/array
# Injecting event spikes found at 35560 locations in the frame
#
# Processing frame 314 of the event spikes video/array
# Injecting event spikes found at 35415 locations in the frame
#
# Processing frame 315 of the event spikes video/array
# Injecting event spikes found at 39192 locations in the frame
#
# Processing frame 316 of the event spikes video/array
# Injecting event spikes found at 37640 locations in the frame
#
# Processing frame 317 of the event spikes video/array
# Injecting event spikes found at 31226 locations in the frame
#
# Processing frame 318 of the event spikes video/array
# Injecting event spikes found at 26563 locations in the frame
#
# Processing frame 319 of the event spikes video/array
# Injecting event spikes found at 29511 locations in the frame
#
# Processing frame 320 of the event spikes video/array
# Injecting event spikes found at 26017 locations in the frame
#
# Processing frame 321 of the event spikes video/array
# Injecting event spikes found at 19066 locations in the frame
#
# Processing frame 322 of the event spikes video/array
# Injecting event spikes found at 15943 locations in the frame
#
# Processing frame 323 of the event spikes video/array
# Injecting event spikes found at 16291 locations in the frame
#
# Processing frame 324 of the event spikes video/array
# Injecting event spikes found at 16970 locations in the frame
#
# Processing frame 325 of the event spikes video/array
# Injecting event spikes found at 18643 locations in the frame
#
# Processing frame 326 of the event spikes video/array
# Injecting event spikes found at 17062 locations in the frame
#
# Processing frame 327 of the event spikes video/array
# Injecting event spikes found at 13647 locations in the frame
#
# Processing frame 328 of the event spikes video/array
# Injecting event spikes found at 14265 locations in the frame
#
# Processing frame 329 of the event spikes video/array
# Injecting event spikes found at 13728 locations in the frame
#
# Processing frame 330 of the event spikes video/array
# Injecting event spikes found at 14831 locations in the frame
#
# Processing frame 331 of the event spikes video/array
# Injecting event spikes found at 13136 locations in the frame
#
# Processing frame 332 of the event spikes video/array
# Injecting event spikes found at 10509 locations in the frame
#
# Processing frame 333 of the event spikes video/array
# Injecting event spikes found at 6725 locations in the frame
#
# Processing frame 334 of the event spikes video/array
# Injecting event spikes found at 4676 locations in the frame
#
# Processing frame 335 of the event spikes video/array
# Injecting event spikes found at 3935 locations in the frame
#
# Processing frame 336 of the event spikes video/array
# Injecting event spikes found at 3110 locations in the frame
#
# Processing frame 337 of the event spikes video/array
# Injecting event spikes found at 3569 locations in the frame
#
# Processing frame 338 of the event spikes video/array
# Injecting event spikes found at 4509 locations in the frame
#
# Processing frame 339 of the event spikes video/array
# Injecting event spikes found at 4929 locations in the frame
#
# Processing frame 340 of the event spikes video/array
# Injecting event spikes found at 4943 locations in the frame
#
# Processing frame 341 of the event spikes video/array
# Injecting event spikes found at 5477 locations in the frame
#
# Processing frame 342 of the event spikes video/array
# Injecting event spikes found at 6746 locations in the frame
#
# Processing frame 343 of the event spikes video/array
# Injecting event spikes found at 6426 locations in the frame
#
# Processing frame 344 of the event spikes video/array
# Injecting event spikes found at 6352 locations in the frame
#
# Processing frame 345 of the event spikes video/array
# Injecting event spikes found at 8032 locations in the frame
#
# Processing frame 346 of the event spikes video/array
# Injecting event spikes found at 7989 locations in the frame
#
# Processing frame 347 of the event spikes video/array
# Injecting event spikes found at 6414 locations in the frame
#
# Processing frame 348 of the event spikes video/array
# Injecting event spikes found at 5729 locations in the frame
#
# Processing frame 349 of the event spikes video/array
# Injecting event spikes found at 6544 locations in the frame
#
# Processing frame 350 of the event spikes video/array
# Injecting event spikes found at 7886 locations in the frame
#
# Processing frame 351 of the event spikes video/array
# Injecting event spikes found at 11412 locations in the frame
#
# Processing frame 352 of the event spikes video/array
# Injecting event spikes found at 14295 locations in the frame
#
# Processing frame 353 of the event spikes video/array
# Injecting event spikes found at 15384 locations in the frame
#
# Processing frame 354 of the event spikes video/array
# Injecting event spikes found at 16701 locations in the frame
#
# Processing frame 355 of the event spikes video/array
# Injecting event spikes found at 17050 locations in the frame
#
# Processing frame 356 of the event spikes video/array
# Injecting event spikes found at 15785 locations in the frame
#
# Processing frame 357 of the event spikes video/array
# Injecting event spikes found at 15292 locations in the frame
#
# Processing frame 358 of the event spikes video/array
# Injecting event spikes found at 15390 locations in the frame
#
# Processing frame 359 of the event spikes video/array
# Injecting event spikes found at 15386 locations in the frame
#
# Processing frame 360 of the event spikes video/array
# Injecting event spikes found at 13546 locations in the frame
#
# Processing frame 361 of the event spikes video/array
# Injecting event spikes found at 12238 locations in the frame
#
# Processing frame 362 of the event spikes video/array
# Injecting event spikes found at 10390 locations in the frame
#
# Processing frame 363 of the event spikes video/array
# Injecting event spikes found at 7834 locations in the frame
#
# Processing frame 364 of the event spikes video/array
# Injecting event spikes found at 6082 locations in the frame
#
# Processing frame 365 of the event spikes video/array
# Injecting event spikes found at 5281 locations in the frame
#
# Processing frame 366 of the event spikes video/array
# Injecting event spikes found at 4151 locations in the frame
#
# Processing frame 367 of the event spikes video/array
# Injecting event spikes found at 3293 locations in the frame
#
# Processing frame 368 of the event spikes video/array
# Injecting event spikes found at 4357 locations in the frame
#
# Processing frame 369 of the event spikes video/array
# Injecting event spikes found at 5476 locations in the frame
#
# Processing frame 370 of the event spikes video/array
# Injecting event spikes found at 7192 locations in the frame
#
# Processing frame 371 of the event spikes video/array
# Injecting event spikes found at 9441 locations in the frame
#
# Processing frame 372 of the event spikes video/array
# Injecting event spikes found at 11237 locations in the frame
#
# Processing frame 373 of the event spikes video/array
# Injecting event spikes found at 13679 locations in the frame
#
# Processing frame 374 of the event spikes video/array
# Injecting event spikes found at 14660 locations in the frame
#
# Processing frame 375 of the event spikes video/array
# Injecting event spikes found at 15162 locations in the frame
#
# Processing frame 376 of the event spikes video/array
# Injecting event spikes found at 14926 locations in the frame
#
# Processing frame 377 of the event spikes video/array
# Injecting event spikes found at 13696 locations in the frame
#
# Processing frame 378 of the event spikes video/array
# Injecting event spikes found at 12163 locations in the frame
#
# Processing frame 379 of the event spikes video/array
# Injecting event spikes found at 11302 locations in the frame
#
# Processing frame 380 of the event spikes video/array
# Injecting event spikes found at 9478 locations in the frame
#
# Processing frame 381 of the event spikes video/array
# Injecting event spikes found at 8508 locations in the frame
#
# Processing frame 382 of the event spikes video/array
# Injecting event spikes found at 8598 locations in the frame
#
# Processing frame 383 of the event spikes video/array
# Injecting event spikes found at 7887 locations in the frame
#
# Processing frame 384 of the event spikes video/array
# Injecting event spikes found at 8426 locations in the frame
#
# Processing frame 385 of the event spikes video/array
# Injecting event spikes found at 9539 locations in the frame
#
# Processing frame 386 of the event spikes video/array
# Injecting event spikes found at 10625 locations in the frame
#
# Processing frame 387 of the event spikes video/array
# Injecting event spikes found at 11118 locations in the frame
#
# Processing frame 388 of the event spikes video/array
# Injecting event spikes found at 12183 locations in the frame
#
# Processing frame 389 of the event spikes video/array
# Injecting event spikes found at 13918 locations in the frame
#
# Processing frame 390 of the event spikes video/array
# Injecting event spikes found at 13516 locations in the frame
#
# Processing frame 391 of the event spikes video/array
# Injecting event spikes found at 12314 locations in the frame
#
# Processing frame 392 of the event spikes video/array
# Injecting event spikes found at 10989 locations in the frame
#
# Processing frame 393 of the event spikes video/array
# Injecting event spikes found at 10868 locations in the frame
#
# Processing frame 394 of the event spikes video/array
# Injecting event spikes found at 10653 locations in the frame
#
# Processing frame 395 of the event spikes video/array
# Injecting event spikes found at 9800 locations in the frame
#
# Processing frame 396 of the event spikes video/array
# Injecting event spikes found at 9065 locations in the frame
#
# Processing frame 397 of the event spikes video/array
# Injecting event spikes found at 8962 locations in the frame
#
# Processing frame 398 of the event spikes video/array
# Injecting event spikes found at 8821 locations in the frame
#
# Processing frame 399 of the event spikes video/array
# Injecting event spikes found at 8669 locations in the frame
#
# Processing frame 400 of the event spikes video/array
# Injecting event spikes found at 7229 locations in the frame
#
# Processing frame 401 of the event spikes video/array
# Injecting event spikes found at 6762 locations in the frame
#
# Processing frame 402 of the event spikes video/array
# Injecting event spikes found at 6991 locations in the frame
#
# Processing frame 403 of the event spikes video/array
# Injecting event spikes found at 7729 locations in the frame
#
# Processing frame 404 of the event spikes video/array
# Injecting event spikes found at 7874 locations in the frame
#
# Processing frame 405 of the event spikes video/array
# Injecting event spikes found at 7678 locations in the frame
#
# Processing frame 406 of the event spikes video/array
# Injecting event spikes found at 7953 locations in the frame
#
# Processing frame 407 of the event spikes video/array
# Injecting event spikes found at 7784 locations in the frame
#
# Processing frame 408 of the event spikes video/array
# Injecting event spikes found at 7187 locations in the frame
#
# Processing frame 409 of the event spikes video/array
# Injecting event spikes found at 7064 locations in the frame
#
# Processing frame 410 of the event spikes video/array
# Injecting event spikes found at 7266 locations in the frame
#
# Processing frame 411 of the event spikes video/array
# Injecting event spikes found at 7096 locations in the frame
#
# Processing frame 412 of the event spikes video/array
# Injecting event spikes found at 7253 locations in the frame
#
# Processing frame 413 of the event spikes video/array
# Injecting event spikes found at 7248 locations in the frame
#
# Processing frame 414 of the event spikes video/array
# Injecting event spikes found at 7367 locations in the frame
#
# Processing frame 415 of the event spikes video/array
# Injecting event spikes found at 7726 locations in the frame
#
# Processing frame 416 of the event spikes video/array
# Injecting event spikes found at 7462 locations in the frame
#
# Processing frame 417 of the event spikes video/array
# Injecting event spikes found at 7940 locations in the frame
#
# Processing frame 418 of the event spikes video/array
# Injecting event spikes found at 8084 locations in the frame
#
# Processing frame 419 of the event spikes video/array
# Injecting event spikes found at 8203 locations in the frame
#
# Processing frame 420 of the event spikes video/array
# ...
# Injecting event spikes found at 995 locations in the frame
#
# Processing frame 2363 of the event spikes video/array
# Injecting event spikes found at 963 locations in the frame
#
# Processing frame 2364 of the event spikes video/array
# Injecting event spikes found at 1734 locations in the frame
#
# Processing frame 2365 of the event spikes video/array
# Injecting event spikes found at 970 locations in the frame
#
# Processing frame 2366 of the event spikes video/array
# Injecting event spikes found at 1025 locations in the frame
#
# Processing frame 2367 of the event spikes video/array
# Injecting event spikes found at 1046 locations in the frame
#
# Processing frame 2368 of the event spikes video/array
# Injecting event spikes found at 1792 locations in the frame
#
# Processing frame 2369 of the event spikes video/array
# Injecting event spikes found at 1104 locations in the frame
#
# Processing frame 2370 of the event spikes video/array
# Injecting event spikes found at 1124 locations in the frame
#
# Processing frame 2371 of the event spikes video/array
# Injecting event spikes found at 1155 locations in the frame
#
# Processing frame 2372 of the event spikes video/array
# Injecting event spikes found at 1877 locations in the frame
#
# Processing frame 2373 of the event spikes video/array
# Injecting event spikes found at 1259 locations in the frame
#
# Processing frame 2374 of the event spikes video/array
# Injecting event spikes found at 1259 locations in the frame
#
# Processing frame 2375 of the event spikes video/array
# Injecting event spikes found at 1388 locations in the frame
#
# Processing frame 2376 of the event spikes video/array
# Injecting event spikes found at 2168 locations in the frame
#
# Processing frame 2377 of the event spikes video/array
# Injecting event spikes found at 1355 locations in the frame
#
# Processing frame 2378 of the event spikes video/array
# Injecting event spikes found at 1341 locations in the frame
#
# Processing frame 2379 of the event spikes video/array
# Injecting event spikes found at 2151 locations in the frame
#
# Processing frame 2380 of the event spikes video/array
# Injecting event spikes found at 1305 locations in the frame
#
# Processing frame 2381 of the event spikes video/array
# Injecting event spikes found at 1256 locations in the frame
#
# Processing frame 2382 of the event spikes video/array
# Injecting event spikes found at 2145 locations in the frame
#
# Processing frame 2383 of the event spikes video/array
# Injecting event spikes found at 1331 locations in the frame
#
# Processing frame 2384 of the event spikes video/array
# Injecting event spikes found at 1407 locations in the frame
#
# Processing frame 2385 of the event spikes video/array
# Injecting event spikes found at 1442 locations in the frame
#
# Processing frame 2386 of the event spikes video/array
# Injecting event spikes found at 2212 locations in the frame
#
# Processing frame 2387 of the event spikes video/array
# Injecting event spikes found at 1349 locations in the frame
#
# Processing frame 2388 of the event spikes video/array
# Injecting event spikes found at 1280 locations in the frame
#
# Processing frame 2389 of the event spikes video/array
# Injecting event spikes found at 1377 locations in the frame
#
# Processing frame 2390 of the event spikes video/array
# Injecting event spikes found at 1374 locations in the frame
#
# Processing frame 2391 of the event spikes video/array
# Injecting event spikes found at 1315 locations in the frame
#
# Processing frame 2392 of the event spikes video/array
# Injecting event spikes found at 1292 locations in the frame
#
# Processing frame 2393 of the event spikes video/array
# Injecting event spikes found at 1292 locations in the frame
#
# Processing frame 2394 of the event spikes video/array
# Injecting event spikes found at 0 locations in the frame
#
# Processing frame 2395 of the event spikes video/array
# Injecting event spikes found at 1296 locations in the frame
#
# Processing frame 2396 of the event spikes video/array
# Injecting event spikes found at 1267 locations in the frame
#
# Processing frame 2397 of the event spikes video/array
# Injecting event spikes found at 1289 locations in the frame
#
# Processing frame 2398 of the event spikes video/array
# Injecting event spikes found at 1186 locations in the frame
#
# Processing frame 2399 of the event spikes video/array
# Injecting event spikes found at 1250 locations in the frame
#
# Processing frame 2400 of the event spikes video/array
# Injecting event spikes found at 1100 locations in the frame
#
# Processing frame 2401 of the event spikes video/array
# Injecting event spikes found at 1081 locations in the frame
#
# Processing frame 2402 of the event spikes video/array
# Injecting event spikes found at 1023 locations in the frame
#
# Processing frame 2403 of the event spikes video/array
# Injecting event spikes found at 0 locations in the frame
#
# Processing frame 2404 of the event spikes video/array
# Injecting event spikes found at 1085 locations in the frame
#
# Processing frame 2405 of the event spikes video/array
# Injecting event spikes found at 1078 locations in the frame
#
# Processing frame 2406 of the event spikes video/array
# Injecting event spikes found at 1053 locations in the frame
#
# Processing frame 2407 of the event spikes video/array
# Injecting event spikes found at 1057 locations in the frame
#
# Processing frame 2408 of the event spikes video/array
# Injecting event spikes found at 1036 locations in the frame
#
# Processing frame 2409 of the event spikes video/array
# Injecting event spikes found at 1070 locations in the frame
#
# Processing frame 2410 of the event spikes video/array
# Injecting event spikes found at 0 locations in the frame
#
# Processing frame 2411 of the event spikes video/array
# Injecting event spikes found at 901 locations in the frame
#
# Processing frame 2412 of the event spikes video/array
# Injecting event spikes found at 884 locations in the frame
#
# Processing frame 2413 of the event spikes video/array
# Injecting event spikes found at 841 locations in the frame
#
# Processing frame 2414 of the event spikes video/array
# Injecting event spikes found at 808 locations in the frame
#
# Processing frame 2415 of the event spikes video/array
# Injecting event spikes found at 757 locations in the frame
#
# Processing frame 2416 of the event spikes video/array
# Injecting event spikes found at 740 locations in the frame
#
# Processing frame 2417 of the event spikes video/array
# Injecting event spikes found at 0 locations in the frame
#
# Processing frame 2418 of the event spikes video/array
# Injecting event spikes found at 730 locations in the frame
#
# Processing frame 2419 of the event spikes video/array
# Injecting event spikes found at 653 locations in the frame
#
# Processing frame 2420 of the event spikes video/array
# Injecting event spikes found at 701 locations in the frame
#
# Processing frame 2421 of the event spikes video/array
# Injecting event spikes found at 777 locations in the frame
#
# Processing frame 2422 of the event spikes video/array
# Injecting event spikes found at 713 locations in the frame
#
# Processing frame 2423 of the event spikes video/array
# Injecting event spikes found at 723 locations in the frame
#
# Processing frame 2424 of the event spikes video/array
# Injecting event spikes found at 704 locations in the frame
#
# Processing frame 2425 of the event spikes video/array
# Injecting event spikes found at 0 locations in the frame
#
# Processing frame 2426 of the event spikes video/array
# Injecting event spikes found at 711 locations in the frame
#
# Processing frame 2427 of the event spikes video/array
# Injecting event spikes found at 641 locations in the frame
#
# Processing frame 2428 of the event spikes video/array
# Injecting event spikes found at 656 locations in the frame
#
# Processing frame 2429 of the event spikes video/array
# Injecting event spikes found at 720 locations in the frame
#
# Processing frame 2430 of the event spikes video/array
# Injecting event spikes found at 666 locations in the frame
#
# Processing frame 2431 of the event spikes video/array
# Injecting event spikes found at 0 locations in the frame
#
# Processing frame 2432 of the event spikes video/array
# Injecting event spikes found at 652 locations in the frame
#
# Processing frame 2433 of the event spikes video/array
# Injecting event spikes found at 780 locations in the frame
#
# Processing frame 2434 of the event spikes video/array
# Injecting event spikes found at 698 locations in the frame
#
# Processing frame 2435 of the event spikes video/array
# Injecting event spikes found at 722 locations in the frame
#
# Processing frame 2436 of the event spikes video/array
# Injecting event spikes found at 698 locations in the frame
#
# Processing frame 2437 of the event spikes video/array
# Injecting event spikes found at 698 locations in the frame
#
# Processing frame 2438 of the event spikes video/array
# Injecting event spikes found at 666 locations in the frame
#
# Processing frame 2439 of the event spikes video/array
# Injecting event spikes found at 716 locations in the frame
#
# Processing frame 2440 of the event spikes video/array
# Injecting event spikes found at 714 locations in the frame
#
# Processing frame 2441 of the event spikes video/array
# Injecting event spikes found at 777 locations in the frame
#
# Processing frame 2442 of the event spikes video/array
# Injecting event spikes found at 793 locations in the frame
#
# Processing frame 2443 of the event spikes video/array
# Injecting event spikes found at 759 locations in the frame
#
# Processing frame 2444 of the event spikes video/array
# Injecting event spikes found at 772 locations in the frame
#
# Processing frame 2445 of the event spikes video/array
# Injecting event spikes found at 804 locations in the frame
#
# Processing frame 2446 of the event spikes video/array
# Injecting event spikes found at 700 locations in the frame
#
# Processing frame 2447 of the event spikes video/array
# Injecting event spikes found at 1482 locations in the frame
#
# Processing frame 2448 of the event spikes video/array
# Injecting event spikes found at 773 locations in the frame
#
# Processing frame 2449 of the event spikes video/array
# Injecting event spikes found at 801 locations in the frame
#
# Processing frame 2450 of the event spikes video/array
# Injecting event spikes found at 835 locations in the frame
#
# Processing frame 2451 of the event spikes video/array
# Injecting event spikes found at 1499 locations in the frame
#
# Processing frame 2452 of the event spikes video/array
# Injecting event spikes found at 752 locations in the frame
#
# Processing frame 2453 of the event spikes video/array
# Injecting event spikes found at 730 locations in the frame
#
# Processing frame 2454 of the event spikes video/array
# Injecting event spikes found at 795 locations in the frame
#
# Processing frame 2455 of the event spikes video/array
# Injecting event spikes found at 1451 locations in the frame
#
# Processing frame 2456 of the event spikes video/array
# Injecting event spikes found at 731 locations in the frame
#
# Processing frame 2457 of the event spikes video/array
# Injecting event spikes found at 916 locations in the frame
#
# Processing frame 2458 of the event spikes video/array
# Injecting event spikes found at 747 locations in the frame
#
# Processing frame 2459 of the event spikes video/array
# Injecting event spikes found at 1517 locations in the frame
#
# Processing frame 2460 of the event spikes video/array
# Injecting event spikes found at 658 locations in the frame
#
# Processing frame 2461 of the event spikes video/array
# Injecting event spikes found at 678 locations in the frame
#
# Processing frame 2462 of the event spikes video/array
# Injecting event spikes found at 1461 locations in the frame
#
# Processing frame 2463 of the event spikes video/array
# Injecting event spikes found at 627 locations in the frame
#
# Processing frame 2464 of the event spikes video/array
# Injecting event spikes found at 657 locations in the frame
#
# Processing frame 2465 of the event spikes video/array
# Injecting event spikes found at 696 locations in the frame
#
# Processing frame 2466 of the event spikes video/array
# Injecting event spikes found at 1259 locations in the frame
#
# Processing frame 2467 of the event spikes video/array
# Injecting event spikes found at 619 locations in the frame
#
# Processing frame 2468 of the event spikes video/array
# Injecting event spikes found at 703 locations in the frame
#
# Processing frame 2469 of the event spikes video/array
# Injecting event spikes found at 1556 locations in the frame
#
# Processing frame 2470 of the event spikes video/array
# Injecting event spikes found at 662 locations in the frame
#
# Processing frame 2471 of the event spikes video/array
# Injecting event spikes found at 739 locations in the frame
#
# Processing frame 2472 of the event spikes video/array
# Injecting event spikes found at 1355 locations in the frame
#
# Processing frame 2473 of the event spikes video/array
# Injecting event spikes found at 674 locations in the frame
#
# Processing frame 2474 of the event spikes video/array
# Injecting event spikes found at 641 locations in the frame
#
# Processing frame 2475 of the event spikes video/array
# Injecting event spikes found at 683 locations in the frame
#
# Processing frame 2476 of the event spikes video/array
# Injecting event spikes found at 1251 locations in the frame
#
# Processing frame 2477 of the event spikes video/array
# Injecting event spikes found at 600 locations in the frame
#
# Processing frame 2478 of the event spikes video/array
# Injecting event spikes found at 650 locations in the frame
#
# Processing frame 2479 of the event spikes video/array
# Injecting event spikes found at 1186 locations in the frame
#
# Processing frame 2480 of the event spikes video/array
# Injecting event spikes found at 537 locations in the frame
#
# Processing frame 2481 of the event spikes video/array
# Injecting event spikes found at 739 locations in the frame
#
# Processing frame 2482 of the event spikes video/array
# Injecting event spikes found at 644 locations in the frame
#
# Processing frame 2483 of the event spikes video/array
# Injecting event spikes found at 1071 locations in the frame
#
# Processing frame 2484 of the event spikes video/array
# Injecting event spikes found at 1027 locations in the frame
#
# Processing frame 2485 of the event spikes video/array
# Injecting event spikes found at 2807 locations in the frame
#
# Processing frame 2486 of the event spikes video/array
# Injecting event spikes found at 6532 locations in the frame
#
# Processing frame 2487 of the event spikes video/array
# Injecting event spikes found at 9894 locations in the frame
#
# Processing frame 2488 of the event spikes video/array
# Injecting event spikes found at 6297 locations in the frame
#
# Processing frame 2489 of the event spikes video/array
# Injecting event spikes found at 6936 locations in the frame
#
# Processing frame 2490 of the event spikes video/array
# Injecting event spikes found at 6048 locations in the frame
#
# Processing frame 2491 of the event spikes video/array
# Injecting event spikes found at 6089 locations in the frame
#
# Processing frame 2492 of the event spikes video/array
# Injecting event spikes found at 6202 locations in the frame
#
# Processing frame 2493 of the event spikes video/array
# Injecting event spikes found at 6087 locations in the frame
#
# Processing frame 2494 of the event spikes video/array
# Injecting event spikes found at 4507 locations in the frame
#
# Processing frame 2495 of the event spikes video/array
# Injecting event spikes found at 2285 locations in the frame
#
# Processing frame 2496 of the event spikes video/array
# Injecting event spikes found at 1458 locations in the frame
#
# Processing frame 2497 of the event spikes video/array
# Injecting event spikes found at 1125 locations in the frame
#
# Processing frame 2498 of the event spikes video/array
# Injecting event spikes found at 807 locations in the frame
#
# Processing frame 2499 of the event spikes video/array
# Injecting event spikes found at 929 locations in the frame
#
# Processing frame 2500 of the event spikes video/array
# Injecting event spikes found at 1036 locations in the frame
#
# Injected 27068177 events into the event data
#
# Saving event data with specified event spikes injected to ./data/event_data/augmented_event.h5

# %% [markdown]
# ### Project object spikes and save to video

# %%
data_path = "data/"

# Should contain an "event_data" folder which iteself contains
# - augmented_event.h5 (with events injected from the previous step)
# - pose.h5 (with the pose data of props)

# The other data files containing translation data, rotation data, etc. should be present
# as per the info (paths) in the info.json file.

# %%
projection(
    data_path=data_path,
    output_video_path="./augmented_event.mp4",
    max_frames=600,
    fps=30,
    augmentation_label=augmentation_events_label,
)
# Out:
# Processing frame 1
# Processing frame 2
# Processing frame 3
# Processing frame 4
# Processing frame 5
# Processing frame 6
# Processing frame 7
# Processing frame 8
# Processing frame 9
# Processing frame 10
# Processing frame 11
# Processing frame 12
# Processing frame 13
# Processing frame 14
# Processing frame 15
# Processing frame 16
# Processing frame 17
# Processing frame 18
# Processing frame 19
# Processing frame 20
# Processing frame 21
# Processing frame 22
# Processing frame 23
# Processing frame 24
# Processing frame 25
# Processing frame 26
# Processing frame 27
# Processing frame 28
# Processing frame 29
# Processing frame 30
# Processing frame 31
# Processing frame 32
# Processing frame 33
# Processing frame 34
# Processing frame 35
# Processing frame 36
# Processing frame 37
# Processing frame 38
# Processing frame 39
# Processing frame 40
# Processing frame 41
# Processing frame 42
# Processing frame 43
# Processing frame 44
# Processing frame 45
# Processing frame 46
# Processing frame 47
# Processing frame 48
# Processing frame 49
# Processing frame 50
# Processing frame 51
# Processing frame 52
# Processing frame 53
# Processing frame 54
# Processing frame 55
# Processing frame 56
# Processing frame 57
# Processing frame 58
# Processing frame 59
# Processing frame 60
# Processing frame 61
# Processing frame 62
# Processing frame 63
# Processing frame 64
# Processing frame 65
# Processing frame 66
# Processing frame 67
